# %% [markdown]
# # Document Clustering
# ### Using Embeddings

# %%
import json
import os
import random
import pandas as pd
import numpy as np
# from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans

# %% [markdown]
# #### Define Parameters

# %%
n_clusters = 10 
n_samples = 10
n = 100
batch_size=64

# %% [markdown]
# ## Load Data

# %%
embeddings = np.load('data/embeddings_cleaned.npy')
embeddings.shape
# Out:
# (935818, 768)

# %%
df = pd.read_csv('data/full_transcripts_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0         series            episode  line   char  \
# 0           0  critical role  The_Echo_Tree.txt     0   MATT
# 1           1  critical role  The_Echo_Tree.txt     1  LAURA
# 2           2  critical role  The_Echo_Tree.txt     2   MATT
# 3           3  critical role  The_Echo_Tree.txt     3  LAURA
# 4           4  critical role  The_Echo_Tree.txt     4   MATT
#
#                                                 text
# 0                                         (laughing)
# 1   And welcome back to tonight's episode. So, pi...
# 2                                              Yeah.
# 3   It's been a long week. However, you guys have...
# 4                                      Ahh, totally.

# %% [markdown]
# ## Define Output Functions

# %%
def sample_clusters(labels, n_clusters = n_clusters, n_samples = 10):
    df['labels'] = labels
    for i in range(n_clusters):
        print(f'Cluster {i}: {len(df[df.labels == i])} / {len(df)}')
        sample = df[df.labels == i].sample(n_samples, replace=True)['text']
        for x in sample:
            print('\t- ' + x[:100])
        print('\n')
        print('==='*30)
        print('\n')

# %% [markdown]
# ## 5 Clusters

# %%
n_clusters = 5 
n_samples = 10

# %%
kmeans = MiniBatchKMeans(n_clusters = n_clusters, random_state= 42, batch_size=2048, max_iter=500)
kmeans = kmeans.fit(embeddings)
sample_clusters(kmeans.labels_, n_clusters=n_clusters, n_samples=n_samples)
# Out:
# Cluster 0: 80033 / 935818
# 	-  Yes, yeah.
# 	-  Yeah.
# 	-  Yep.
# 	-  All righty.
# 	-  Okay!
# 	-  Yeah.
# 	-  Yes?
# 	-  Okay!
# 	-  All right.
# 	-  Sure.
#
#
# ==========================================================================================
#
#
# Cluster 1: 182804 / 935818
# 	-  Fjord, you're on deck.
# 	-  Can we hide?
# 	-  I have Guidance.
# 	-  Amazing. You rise back up to face the erinyes above you. Following your turn, it is going to be the
# 	-  "Right." He tightens his grip on his axe.
# 	-  And passes out again.
# 	-  "Oh. Mom!" Runs in and gives you a big hug. For a second, and then pushes you out and goes, "Hey."
# 	-  (laughing) Make a perception check.
# 	-  Is he going to be looking for me? You got to do what you need to do.
# 	-  We're not going to evacuate several thousand people, it's just not going to happen.
#
#
# ==========================================================================================
#
#
# Cluster 2: 92073 / 935818
# 	-  Plus performance.
# 	-  Rolled a natural 18, so 28.
# 	-  Does a 17 hit?
# 	-  That's a bad one. Eight.
# 	-  Eyy, that's nine plus three is 12 plus four is 16.
# 	-  That is 14 points of piercing damage.
# 	-  I'll say it's three-quarters cover. That's fine. You get plus five to your AC. 24. What's your AC?
# 	-  All righty, so looking at how things stand here, currently, 25 to 20?
# 	-  17.
# 	-  17. So you hit. This is a contested strength check.
#
#
# ==========================================================================================
#
#
# Cluster 3: 362649 / 935818
# 	-  Did you know Sorudin?
# 	-  Stew's good.
# 	-  Best music video.
# 	-  Oh, it's everything I could have hoped for.
# 	-  Long mane, braided into a plait that comes down her side and then just covered in barding,	covered
# 	-  Yeah, there was stuff in there.
# 	-  We can never come back if we run.
# 	-  Are you fucking kidding me?!
# 	-  Come on, I think we've got some stuff to talk about.
# 	-  Oh, no.
#
#
# ==========================================================================================
#
#
# Cluster 4: 218259 / 935818
# 	-  He does save.
# 	-  And Fjord, I got you... Just like a cleric's... Not a cleric's, a clerk's visor for doing accountin
# 	-  Roll a sleight of hand check. This is against the monk's perception.
# 	-  Okay, then I can walk it.
# 	-  You do, actually, yes. Favored terrain.
# 	-  little domed pieces of stone that once contained flame for light. Across the way you can see two ta
# 	-  It possibly can break, and it seems like it's only three uses within a period of a day cycle.
# 	-  Okay, so I'm going to cast Cure Wounds on myself.
# 	-  The scratch marks are across the ground, it looks just like fingers being pulled through.
# 	-  As the poison begins to pulse into your system, in the moment the pain begins to hit the back of yo
#
#
# ==========================================================================================

# %% [markdown]
# ## 10 Clusters

# %%
n_clusters = 10 
n_samples = 10

# %%
kmeans = MiniBatchKMeans(n_clusters = n_clusters, random_state= 42, batch_size=2048, max_iter=500)
kmeans = kmeans.fit(embeddings)
sample_clusters(kmeans.labels_, n_clusters=n_clusters, n_samples=n_samples)
# Out:
# Cluster 0: 112665 / 935818
# 	-  I mean, it's a bonus action so I can't go very high with the level, can I?
# 	-  Don't hit the turtle.
# 	-  All right so… this would be Counterspell.
# 	-  16 misses. It swings out and you actually catch the spear off to the side and you're now in a stren
# 	-  Make an attack with disadvantage.
# 	-  I can Stone Shape it a little bit thinner.
# 	-  I wrap my hands in cloth, and then I do it.
# 	-  You got it, all right, cool. So you swing out of the way. Pike, you're up. You're conscious, you're
# 	-  No, I don't think, I don't know that I can-- I can't use an unarmed strike because I just used a sp
# 	-  That would be your one attack.
#
#
# ==========================================================================================
#
#
# Cluster 1: 149785 / 935818
# 	-  You could possibly end it.
# 	-  We could still run, I'm just saying.
# 	-  Hold on a second. Are you sure you don't want to smoke this bitch?
# 	-  All right. With a couple of provisions here, all right? One
# 	-  God. Save the plate for FCG.
# 	-  All right, what the fuck are we going to do?
# 	-  No reason to spend all that time by yourself.
# 	-  Depends on if you guys want to follow.
# 	-  Should we disguise ourselves?
# 	-  Yeah, Flip This Bitch.
#
#
# ==========================================================================================
#
#
# Cluster 2: 155585 / 935818
# 	-  Yes, there is.
# 	-  What?
# 	-  Meanwhile.
# 	-  Oh my god.
# 	-  And you know his wife got--
# 	-  Oh no. Oh wow. Okay.
# 	-  That's fair.
# 	-  Ooh!
# 	-  That was my bonus.
# 	-  I wanted to save you circularly arguing about something without some information.
#
#
# ==========================================================================================
#
#
# Cluster 3: 115744 / 935818
# 	-  “All right, fine.” And he opens the door. You guys walk in, and there you see the entirety of the r
# 	-  Where'd the squid come from?
# 	-  Where's Yasha?
# 	-  Is he always this loud?
# 	-  Not their corpses. It's not morbid like that, but Dancer, my former associate, she had made some ot
# 	-  The skeletal one? There's a skeletal one, and there's the one that's been fighting you this whole t
# 	-  Are they into the initiative order, just gameplay talk?
# 	-  You're already a wolf wolf, you can't be a double wolf. Oh my god!
# 	-  Cerrit does not like his name announced.
# 	-  Is it just him wearing the black plate armor–
#
#
# ==========================================================================================
#
#
# Cluster 4: 33035 / 935818
# 	-  No.
# 	-  Yeah.
# 	-  Yeah.
# 	-  Yeah, basically.
# 	-  Yeah.
# 	-  So.
# 	-  Yeah.
# 	-  I think so.
# 	-  Yes.
# 	-  Yes.
#
#
# ==========================================================================================
#
#
# Cluster 5: 57460 / 935818
# 	-  Plus four.
# 	-  Mm, 16. Rough rolls today.
# 	-  12. Yes. You feel a broken sharp-edged tripod leg stab through here and come out here. You take fiv
# 	-  Okay, so 23. Grog, what have you got?
# 	-  15. (counting) You can't quite get to her. You do manage to leap across, parkour off the edges. You
# 	-  Okay. Summer's Dance falchion. That is a 23 to hit.
# 	-  11 plus 17, 21, 26, 29, 34, 39 for the first dagger.
# 	-  15, okay. You rake a canal down this man's back, and he is staggering away down this hall pathetica
# 	-  19!
# 	-  Ah, 17.
#
#
# ==========================================================================================
#
#
# Cluster 6: 28175 / 935818
# 	-  All right. You take--
# 	-  All right.
# 	-  Okay.
# 	-  Okay.
# 	-  Okay.
# 	-  Cool.
# 	-  Okay.
# 	-  Okay.
# 	-  All right.
# 	-  Okay.
#
#
# ==========================================================================================
#
#
# Cluster 7: 44042 / 935818
# 	-  You see a quirked eyebrows as he's like, "I mean, okay. I'm, like, into new stuff. This is-- Sure,
# 	-  I float quickly past everyone and head into the gazebo.
# 	-  “Well, I appreciate your attempt to maneuver around my station of which you hold so clear. You seem
# 	-  "When they're available, those supplies are a bit stretched thin and put toward the front lines. We
# 	-  "Should have something fashioned for you by then. This is just a piece of practice material I can f
# 	-  “Brother.”
# 	-  "That's mine."
# 	-  "You're looking for stuff? That's crazy. That's wild!"
# 	-  “Tary.”
# 	-  She puts her hand up and denies it.
#
#
# ==========================================================================================
#
#
# Cluster 8: 137190 / 935818
# 	-  Aw, man!
# 	-  You're going to die!
# 	-  I read my sheet!
# 	-  (blows raspberry) Boy.
# 	-  (screams) First one, first one, first one. Which of you?
# 	-  You looked real cool earlier with the gun. The first time. Not the time after.
# 	-  pastries?
# 	-  Spin the Bottle!
# 	-  (growls) Rage!
# 	-  Yeah, I feel really pink.
#
#
# ==========================================================================================
#
#
# Cluster 9: 102137 / 935818
# 	-  Correct. It looks night.
# 	-  Yes, literally and you're like, "Here, hold this," and then three seconds later, it's back at your
# 	-  I'm going to carefully keep an eye out for what's around this thing. It feels very trappy to me.
# 	-  Right behind Caduceus, right there.
# 	-  Oh, yeah, climbing equipment.
# 	-  The wall is gone now.
# 	-  So everyone is moving into it?
# 	-  Effective corpses. How far away is Quay? From me.
# 	-  Can you talk to the tree if you're invisible?
# 	-  As you're rummaging through, once again, a lot of materials, errant weapons and such, you do find i
#
#
# ==========================================================================================

# %% [markdown]
# ## 20 Clusters

# %%
n_clusters = 20 
n_samples = 10

# %%
kmeans = MiniBatchKMeans(n_clusters = n_clusters, random_state= 42, batch_size=2048, max_iter=500)
kmeans = kmeans.fit(embeddings)
sample_clusters(kmeans.labels_, n_clusters=n_clusters, n_samples=n_samples)
# Out:
# Cluster 0: 48183 / 935818
# 	-  All right, roll damage.
# 	-  Advantage and one re-roll, if you need it.
# 	-  So I would be the only one who took damage if I hit that thing?
# 	-  Grog is not in melee.
# 	-  I think the target of the attack has to be the target of the Cutting Words. Because yeah, it reduce
# 	-  The little bit of a pull would pull her a little more central and I'm going to use my superiority d
# 	-  You can use an attack to try and disarm it, if you'd like.
# 	-  That was action. Wait, hold on. I will use bonus action to do Second Wind on myself.
# 	-  We reroll ones for hit points.
# 	-  Then do it! Why don't you set a noise out behind it so it chases off in the other direction?
#
#
# ==========================================================================================
#
#
# Cluster 1: 80378 / 935818
# 	-  Okay. Let's go.
# 	-  Yeah cool, I'm just hanging.
# 	-  I'm going to keep looking at coins.
# 	-  I'm going to--
# 	-  Can I use-- oh shit. I'm going shitballs, shit.
# 	-  I'm too scared to do it. I'm too scared to do it. I think he's going to attack us soon. He sounded
# 	-  I'm going to hide behind a tree and watch.
# 	-  Come on.
# 	-  We need to go on vacation.
# 	-  So, hey, Freddie, like, how long do you think guy downstairs will give us to decide?
#
#
# ==========================================================================================
#
#
# Cluster 2: 58055 / 935818
# 	-  What?
# 	-  Jesus Christ.
# 	-  Oh, that's tall.
# 	-  What?
# 	-  Yeah? Go on.
# 	-  Oh boy.
# 	-  Interesting.
# 	-  Oh boy.
# 	-  I don't like that.
# 	-  Oh my god.
#
#
# ==========================================================================================
#
#
# Cluster 3: 26570 / 935818
# 	-  You're so lucky she's not watching right now.
# 	-  Woo! Girl power!
# 	-  I'd better roll for Laura.
# 	-  Don't you take my goblin mom away!
# 	-  I'll run over and give her a big hug on her knees!
# 	-  We also have Furiosa over here, who we could totally get dressed up and do a whole thing and you kn
# 	-  We should tell her, Grog.
# 	-  Someone give Yasha some goddamn javelins.
# 	-  You could see that Yasha, holding Veth on her shoulders, is starting to slightly fall behind, just
# 	-  No one has seemed to see her--
#
#
# ==========================================================================================
#
#
# Cluster 4: 31792 / 935818
# 	-  Yeah.
# 	-  Yeah.
# 	-  Yep.
# 	-  I was asking that, yes.
# 	-  Yep!
# 	-  Yeah.
# 	-  Yeah.
# 	-  Yeah.
# 	-  No.
# 	-  Yeah.
#
#
# ==========================================================================================
#
#
# Cluster 5: 47695 / 935818
# 	-  Is it per day or per short rest?
# 	-  First attack. Yep, that's good. 21!
# 	-  And nine points of damage.
# 	-  Oh my god, it's cocked! You don't get to keep it, but it was like, "20, fuck you," at an angle.
# 	-  I only had 45 hit points.
# 	-  23, oof! As it slams into the creature, the burning, radiant energy courses across its torso and he
# 	-  It's still a two, though. Plus?
# 	-  Those are you first two fails?
# 	-  First, it's going to attempt to bite you. Gets a natural 20.
# 	-  Oh! And third one is a 25.
#
#
# ==========================================================================================
#
#
# Cluster 6: 24202 / 935818
# 	-  Okay.
# 	-   Okay.
# 	-  OK, OK.
# 	-  Okay, okay.
# 	-  All right, all right.
# 	-  Sorry.
# 	-  Okay.
# 	-  Okay.
# 	-  Okay, cool.
# 	-  Okay, okay.
#
#
# ==========================================================================================
#
#
# Cluster 7: 29666 / 935818
# 	-  “Of course!” He tucks it away. “Thank you!”
# 	-  "I shall. Thank you very much."
# 	-  “Well, I know of a man of you describe, of blueish skin and quite sweaty. Yes, he has come through
# 	-  "That, I kind of believe."
# 	-  “This girl that you keep talking about, right?”
# 	-  "Yeah, more or less."
# 	-  "Not directly, but I know how deeply the loss can be."
# 	-  "And we always hoped that you'd... that you'd improve, and at times you did, and... I mean, to be h
# 	-  “Shedulable.”
# 	-  "If the rest of your friends complete the contract, your soul is fine."
#
#
# ==========================================================================================
#
#
# Cluster 8: 24765 / 935818
# 	-  Oh boy! (laughs)
# 	-  Okay. So looking through Frumpkin's eyes, Frumpkin--
# 	-  Here we go. (laughter)
# 	-  Get in the middle, Caleb.[laughter]
# 	-  (groans)
# 	-  (laughs)
# 	-  No. No chance.(laughter)
# 	-  (yells)
# 	-  (chuckles)
# 	-  Before looping back around. (laughter)
#
#
# ==========================================================================================
#
#
# Cluster 9: 53069 / 935818
# 	-  Okay. I'm going to head back and look at the entrance.
# 	-  21, okay. As you get down in there, there is a heavy mist, sourceless, that gets heavier, denser an
# 	-  Ooh, look at this map.
# 	-  This corner?
# 	-  And if you recall– good memory– in the Frostweald, the partially frozen forest where you had that c
# 	-  You can see near, but these are things that are a mile away.
# 	-  The keep. For little sneaky holes that I didn't know were there.
# 	-  It's super, super calm.
# 	-  At the very back.
# 	-  The city is in the Plane of Fire.
#
#
# ==========================================================================================
#
#
# Cluster 10: 56421 / 935818
# 	-  No, you're just floating in space.
# 	-  We're very particular about them.
# 	-  Today, we're playing New Super Mario Bros. U Deluxe. This one's a lot of fun and one of my favorite
# 	-  We have to be very careful.
# 	-  We need that.
# 	-  No, by each other.
# 	-  Avoidance is the way of peace.
# 	-  They don't. They can take advantage of you, or they can lift you up. We've had both. I am loving ev
# 	-  Not specifically in this section, no.
# 	-  Apparently. A lot of you guys came tonight to watch the show. Thank you so much for coming and watc
#
#
# ==========================================================================================
#
#
# Cluster 11: 38780 / 935818
# 	-  I'm going to trace again with my finger the runes.
# 	-  When I could feel their essence, I don't know, it was like their blood was made of all of the chemi
# 	-  I do if it's fey, fiend, or undead.
# 	-  Mr. Caleb, maybe do we want to send a creature, a flying creature maybe?
# 	-  So it doesn't do anything. So then I'll scan through the stuff, looking for magical dope items–
# 	-  I get a new blood curse. I want to have a conversation about that before we go into that.
# 	-  I'm going to use Thaumaturgy to get the fires going a little hotter again. Going to make the lights
# 	-  All right, you understand this creature is immune to cold and fire damage.[gasping]
# 	-  Detect undead.
# 	-  I'm going to take a walk around this little ruin. I'm going to have the little Light spell up, see
#
#
# ==========================================================================================
#
#
# Cluster 12: 57811 / 935818
# 	-  Oh, sorry, he's been talking shit about you this whole time, I don't know, I just--
# 	-  Moom. Moombeam.TJ, TRAVIS, and LAURA
# 	-  That's very Beau, though.
# 	-  Veth is next to Caleb. Beau is next to Yasha.
# 	-  God, you could seduce him.
# 	-  No, I bet he's in the fucking Nine Hells right now.
# 	-  Benicio.
# 	-  (chants) Dax-i-o. Daxio!
# 	-  So he's not behaving any differently at all? He just has jet black shark eyes?
# 	-  Trinket's right here.
#
#
# ==========================================================================================
#
#
# Cluster 13: 76228 / 935818
# 	-  What am I rolling?
# 	-  Killing?
# 	-  Don't know?
# 	-  One minute.
# 	-  Not anything crazy?
# 	-  Dude, this place is amazing!
# 	-  What are you bringing that out for now?
# 	-  PBR?
# 	-  First blood!
# 	-  I take off flying.
#
#
# ==========================================================================================
#
#
# Cluster 14: 20333 / 935818
# 	-  The dust settles, the adrenaline still pumping in your system, Scanlan. All the rest of the dwarves
# 	-  And I bring out the stupid pointy hat that he gave me.
# 	-  Meets you part way, looks to you. You can see underneath the helmet, the eyes are not trusting. You
# 	-  You turn around and on the deck you see, freshly arrived, a half-elven woman, with short, brown hai
# 	-  And she slinks over towards the doorways that lead into the lower part of the deck. As you guys lea
# 	-  (like Sean Connery) Going to cleanse the room of spirits!(laughter)
# 	-  "Is that literal? I'm going to talk to you, or you, no, I don't want to talk to you. You, you, hey.
# 	-  As you hand it out, she grabs it from your hands–
# 	-  I walk off.
# 	-  (sighs) “I fear the Herd's lost its edge. Priorities. My father had grown docile in this place. But
#
#
# ==========================================================================================
#
#
# Cluster 15: 54997 / 935818
# 	-  Can you see if he was diseased or--
# 	-  Taliesin--
# 	-  Not insects.
# 	-  Directly to its eye.
# 	-  That are slertly-- slightly merged.
# 	-  They make those?
# 	-  Can I do a check to see if I recognize any of these things?
# 	-  It's acute?
# 	-  Do you know Undercommon?
# 	-  Well, more for me, I guess. Birds. It's pretty cool, though. (laughter) He puts it in his pocket an
#
#
# ==========================================================================================
#
#
# Cluster 16: 66236 / 935818
# 	-  Oh, I try to save from it!
# 	-  Yeah, yeah, yeah. Did not work. (laughter)
# 	-  Oh, you mean to cover my beard?
# 	-  It's coming out of me like lava! (laughter)
# 	-  How could you have my back if it's on me?
# 	-  Oh lord, no. This is bad.
# 	-  That's nice. That's good. Hold on, I've got– I pull out whatever the hell was growing in my pouch a
# 	-  Did that suffice?
# 	-  I've been practicing. Let me try.
# 	-  Chop it off!
#
#
# ==========================================================================================
#
#
# Cluster 17: 27874 / 935818
# 	-  Five.
# 	-  I'm going to use a blue one, because it's frosty. That would be 31. No, wait, no, that's a lie. Tha
# 	-  27.
# 	-  21.
# 	-  16.
# 	-  Six.
# 	-  18 plus two is 20.
# 	-  25 to 20.
# 	-  18!
# 	-  47.
#
#
# ==========================================================================================
#
#
# Cluster 18: 50799 / 935818
# 	-  Okay. You guys gather your horses, fresh warhorse and saddlebags upon yours as well, Tiberius. Fine
# 	-  Just grab him and put him in the bag of holding!
# 	-  He's definitely passed out. He's not dead, but there is a large amount of blood coming out of his s
# 	-  So you take 17 points of force damage, as the creature comes out and goes (casts spell) and throws
# 	-  Jarett got the door open, he came through to try and grab the creature, and as he tried to pull it
# 	-  Okay, question, do I see the person that's carrying me since we're both invisible now?
# 	-  I need to get to him. I'm going to try. (sighs) I'm going to try to use whatever I can with my body
# 	-  It's a scale in the right direction. So Keg, as you hold up your plates a bit, like you're trying t
# 	-  So you guys all take a breath as the water wall collapses behind you, rushes up, and like a water j
# 	-  The two of you limp down to one of the tiny little seedy bars that doesn't even have a name on the
#
#
# ==========================================================================================
#
#
# Cluster 19: 61964 / 935818
# 	-  I could go ask. I mean, I could go and get a few buzz-words, you know--
# 	-  I bet Steamforged can make it for ya.
# 	-  We have a hard time keeping track of everyone that we hire and fire.
# 	-  Yes, that's a good idea.
# 	-  I have minor control of that.
# 	-  You're gambling on jealousy.
# 	-  A spot hidden will get me something better, I'm assuming.
# 	-  Don't complicate things.
# 	-  They wouldn't do that.
# 	-  Oh. I will in 10 minutes.
#
#
# ==========================================================================================

# %% [markdown]
# ## 50 Clusters

# %%
n_clusters = 50 
n_samples = 10

# %%
kmeans = MiniBatchKMeans(n_clusters = n_clusters, random_state= 42, batch_size=2048, max_iter=500)
kmeans = kmeans.fit(embeddings)
sample_clusters(kmeans.labels_, n_clusters=n_clusters, n_samples=n_samples)
# Out:
# Cluster 0: 28088 / 935818
# 	-  Here we go. I knew you were my brother.
# 	-  You look great.
# 	-  ♪ My hump, my hump, my hump, my hump ♪
# 	-  That's so cool.
# 	-  Thank you to our amazing crew.
# 	-  All right, and Tova's standing there looking strong and the camera's turning around her. It's like
# 	-  I-- I made my own little placard for the-- I made my little cards.
# 	-  Peachy-peachy.
# 	-  I'm being a nerd. Have fun!
# 	-  You'll thank me later. I'm just going to bap the sheet.
#
#
# ==========================================================================================
#
#
# Cluster 1: 23171 / 935818
# 	-  It's present.
# 	-  Cut the feed, cut the feed.
# 	-  To what?
# 	-  Next year. That's right! Yeah, yeah. Oh my god. Aaah! Next year in 2021.
# 	-  Which one?
# 	-  It's true. Up.
# 	-  The theme's running.
# 	-  I'm just going to say
# 	-  This is you, this is it right here.
# 	-  Sit down.
#
#
# ==========================================================================================
#
#
# Cluster 2: 18109 / 935818
# 	-  I need some supplies.
# 	-  Do we have glitter?
# 	-  I bought them. But I want Tiberius to make me more.
# 	-  Sure, yes. How much for four healing potions?
# 	-  How long have you had this relic?
# 	-  For what?
# 	-  Are there any potion shops around here?
# 	-  Oh, we do have the earrings in?
# 	-  Is there any remnants of precious metals, coals, things that would be mined?
# 	-  I think I could make you one large, lumpy diamond worth less than what you started with.
#
#
# ==========================================================================================
#
#
# Cluster 3: 15313 / 935818
# 	-  "Well, it was believed that perhaps this missing beacon of which I'd sent you to seek itself was so
# 	-  “She had five individuals following her, aye.”
# 	-  "You can pay now if you want to, but--"
# 	-  “The airship we don't know quite exactly where it is and when it will arrive. I don't know if we ca
# 	-  "The spell is over."
# 	-  "All right. And... fight." [laughter] Roll initiative.
# 	-  "I can. Understand, I know the memory lapses are challenging. But those of us of the Vo, we were ch
# 	-  Okay. He goes, "Eshteross is an upstanding individual, a bit of a recluse. I'm glad to see that he'
# 	-  "I had my heart beaten out of me a long time ago. Now, it's about guiding history. It always has be
# 	-  "What is happening? Do you require an adult? Can someone else with-- What's your name?"
#
#
# ==========================================================================================
#
#
# Cluster 4: 37472 / 935818
# 	-  That misses.
# 	-  Not my strong suit.
# 	-  Because I don't remember a full week.
# 	-  Hmm?
# 	-  It lacks a certain pizazz, a certain, je ne sais quoi, a certain oomph. So if you would have me, I
# 	-  I doubt it.
# 	-  That is a good question.
# 	-  It's a ritual, though, is that–
# 	-  I just thought there would be other stats. BRIAN
# 	-  How?
#
#
# ==========================================================================================
#
#
# Cluster 5: 20265 / 935818
# 	-  Before-- I need both of you to roll dexterity saving throws for me, please.
# 	-  I need your spider to make a constitution saving throw, please.
# 	-  Yeah, I'll hold my action until he gets within range, if he does.
# 	-  All right. Well. I'm far away from him, but Grog's right next to him, so I probably shouldn't do an
# 	-  I don't think we need to, right? We're completely healed plus 10?
# 	-  Trinket stays awake with you, though.
# 	-  I'll allow it. If you still have the temporary hit points.
# 	-  I'll be behind Caduceus.
# 	-  Gods. Dead. Five Seconds. Hard to beat.
# 	-  Yasha would like to rage. She will rush the traffic cone from hell that is attacking Caduceus and C
#
#
# ==========================================================================================
#
#
# Cluster 6: 21114 / 935818
# 	-  Oh, because it's a racial ability?
# 	-  So I'm going to say you have an opportunity attack as it moves through the center of the group.
# 	-  Keyleth, however, you are carrying two gnomes, so you have a disadvantage on it.
# 	-  Well, you can use a bonus action to fire with your hand crossbow at him if you want to.
# 	-  You succeed and take no damage because of your Evasion ability.
# 	-  Disadvantage for the?
# 	-  It succeeds the save.
# 	-  So no Hunter's Mark, but you hit it with the Lightning Arrow. Next round you can worry about that.
# 	-  Yeah, but I'm not using the axe or the hammer, I'm using the sword.
# 	-  All right, go ahead and make a grapple check. Roll athletics again, with the earth elemental's stre
#
#
# ==========================================================================================
#
#
# Cluster 7: 14824 / 935818
# 	-  16.
# 	-  And 14?
# 	-  17.
# 	-  23?
# 	-  Reckless.15.
# 	-  18.
# 	-  12.
# 	-  Really? You're not going to let that slide? 19!
# 	-  31.
# 	-  Oh my god. 19.
#
#
# ==========================================================================================
#
#
# Cluster 8: 11739 / 935818
# 	-  Fuck!
# 	-  Look at that!
# 	-  Ooh!
# 	-  Yes!
# 	-  Yeah?
# 	-  Yeah, yeah, yeah, yeah.
# 	-  It could be great!
# 	-  Yes! (screaming)
# 	-  Yeah!
# 	-  Oh, sir!
#
#
# ==========================================================================================
#
#
# Cluster 9: 19578 / 935818
# 	-  All right.
# 	-  Okay.
# 	-  Okay.
# 	-  All right.
# 	-  All right.
# 	-  Okay.
# 	-  Okay.
# 	-  All right.
# 	-  Okay.
# 	-  All right.
#
#
# ==========================================================================================
#
#
# Cluster 10: 18467 / 935818
# 	-  Thank you, everyone. Five, plus Wisdom which I think is four, which is four, so nine.
# 	-  I know, you keep saying that number, like I know what it means, so let's get it on.
# 	-  No, no. Plus one, so now it's two.
# 	-  Three zeros.
# 	-  Oh, how many?
# 	-  Which is a minus two, right?
# 	-  Minus four.
# 	-  Three successes? You do not give a little squirt of poop, then. Well done.
# 	-  Four.
# 	-  That's halved.
#
#
# ==========================================================================================
#
#
# Cluster 11: 19095 / 935818
# 	-  The shadows take your eyes and sight and you reach out to put your hands on the wall to stop yourse
# 	-  All right, so at this point the woman pulls an amulet. The woman pulls an amulet out from beneath t
# 	-  All right. You guys take this information in, communally form a deep breath, and begin to make your
# 	-  115 pages in you get to a page that seems to talk about the sorrow of a lost romance, and trying to
# 	-  I think we have to go back on the airship to go get it.
# 	-  You gather that it is strange that they're out. Though it is getting later in the day, you are push
# 	-  And even though you all don't hear it, you hear a small hitch of breath, a sigh of remembrance, and
# 	-  I am thinking-- We're all kind of exhausted. I'm just thinking maybe we just shouldn't go downstair
# 	-  The tome closes, and you watch as it almost seems to spark and scatter away into nothing.
# 	-  I fly back to the others.
#
#
# ==========================================================================================
#
#
# Cluster 12: 30062 / 935818
# 	-  Who has the higher dex?
# 	-  Is its name Roy?
# 	-  This one's name is Bluute?
# 	-  The regular gnoll.
# 	-  Percy's like (babbling)
# 	-  That sounds Elvish, but it's not.
# 	-  I was trying to remember which-- part of members of the group were dist--
# 	-  What's your typical rank on board ship if you don't mind me asking?
# 	-  Hi. I'm Dusk.
# 	-  No, yeah, the pervy rabbit.
#
#
# ==========================================================================================
#
#
# Cluster 13: 23426 / 935818
# 	-  I was going to ask if it looks the same as the boats of the day or how old it seems.
# 	-  The glass.
# 	-  How wide across is this well? Skinny, or pretty wide?
# 	-  What form?
# 	-  That fucking doorbell.
# 	-  Thank you. God, what is this?
# 	-  A random pattern.
# 	-  Rabbit.
# 	-  Giant miniatures of space unicorns. However, even though you rolled really poorly, your watch goes
# 	-  What are you drawing?
#
#
# ==========================================================================================
#
#
# Cluster 14: 21269 / 935818
# 	-  Yeah.
# 	-  Yeah.
# 	-  Yes.
# 	-  Yep.
# 	-  Correct.
# 	-  Yes.
# 	-  Yeah.
# 	-  Yeah.
# 	-  Yeah.
# 	-  Yeah.
#
#
# ==========================================================================================
#
#
# Cluster 15: 15503 / 935818
# 	-  Okay. About ten minutes of you guys searching as you travel southward among this… okay. You guys wa
# 	-  This wasn't the room.
# 	-  Do I find the jewel?
# 	-  Suddenly, the top one folds over and slams into the ground, tumbling across the center in a wild di
# 	-  Anything interesting on the wall?
# 	-  Is the temple to Sarenrae on the way to the–
# 	-  What happened when we folded it up? Come out of there!
# 	-  And how is morale? Everyone have enough supplies and ready to defend the fort if needed?
# 	-  We also have the dodecahedron.
# 	-  There's no windows here. It's a casino.
#
#
# ==========================================================================================
#
#
# Cluster 16: 15043 / 935818
# 	-   Then you arrive here. Oh, all right.
# 	-  Going into--yeah.
# 	-  So wait, are you from another dimension? You said you came through a portal, or something. Does tha
# 	-  Just ride it out. Rushing at the room.
# 	-  No, the teleportation circle will be in another room, the one that leads--
# 	-  Should I check the door for traps?
# 	-  Wait, I would say wait till we have the door open, because then we can move around a little bit. Be
# 	-  Show me up, why don't you.(laughter)
# 	-  Let's just keep walking very quietly.
# 	-  How did they get in here? How did you get in here?
#
#
# ==========================================================================================
#
#
# Cluster 17: 21548 / 935818
# 	-  Can I assist her in that? Because I'm feeling that same way.
# 	-  It's a fair point. We don't want to be corrupted by the very evil that we mean to stamp out in this
# 	-  Well, I mean, can we– I mean, we don't wanna stop her I just wanna be like, hey, slow, girl.
# 	-  It is Portia's turn.
# 	-  Yes. I mean, that's beside the point. Pike was glorious and wonderful and confident, and I miss her
# 	-  What is with this bitch?
# 	-  Let's go. Kick down her door. Break all of her plates. Eat all of her food.
# 	-  Or hold action until she appears, that's smart.
# 	-  Did I see her do that, by the way?
# 	-  At this point, I feel like Opal would marry Dariax.
#
#
# ==========================================================================================
#
#
# Cluster 18: 12022 / 935818
# 	-  Ooh.
# 	-  Yeah. Wow.
# 	-  Fuck.
# 	-  Mm.
# 	-  Perfect.
# 	-  Dammit.
# 	-  Wow.
# 	-  Wow.
# 	-  Ooh.
# 	-  Excellent.
#
#
# ==========================================================================================
#
#
# Cluster 19: 11199 / 935818
# 	-  Oh, but I get to roll twice though, because it's my favored terrain?
# 	-  All right, go ahead and make a roll, guys. Or one of you with advantage. Your choice.
# 	-  Oh boy. Beauregard, roll perception check for me, please.
# 	-  I rolled an 18.
# 	-  I rolled a 13, plus two, so 15.
# 	-  I rolled an 11.
# 	-  Okay. Oh, I keep rolling, I rolled the same number all three times. 22.
# 	-  You got to roll for it, though.
# 	-  Roll. High.
# 	-  All right, I get a fear of all my dice as soon as we start anything terrible.
#
#
# ==========================================================================================
#
#
# Cluster 20: 17840 / 935818
# 	-  You pull it open. Potion of Superior Healing.
# 	-  That finishes those guys' turn. The stun wears off.
# 	-  So as you fire those two shots, the echoing noises of Bad News's explosions echoes through the hall
# 	-  It hits, it doesn't look like it does as much damage as you're used to it doing, but it does seem t
# 	-  From that place where you had it, you find one of the other grinding bands-- it felt like sandpaper
# 	-  As they both drop, you rush up to the one in the metal armor, who doesn't react to your arrival, st
# 	-  You can't make out too much of the details around him, but he-- at one point early on, you did see
# 	-  You go into your dodge stance, preparing for any sort of assault from head on. That finishes your g
# 	-  Disintegrate toward Pike.
# 	-  Okay. You watch as she takes her glove and puts it back on, looking at her palm as she does. Looks
#
#
# ==========================================================================================
#
#
# Cluster 21: 9593 / 935818
# 	-  No.
# 	-  No.
# 	-  At the moment, no.
# 	-  Why? No.
# 	-  No.
# 	-  No!
# 	-  No. Too many letters.
# 	-  Is this it?
# 	-  Maybe.
# 	-  Seems like it.
#
#
# ==========================================================================================
#
#
# Cluster 22: 15971 / 935818
# 	-  He takes a while to rest up.
# 	-  Orym blooms out a single large flower in his hand and leaves it on the desk amidst the papers that
# 	-  I pore through my notes, I'm actually poring through my notes, but then Beau pores through her note
# 	-  While you're having this conversation, you hear from behind you, "I'm going first!" and Jester just
# 	-  Equally short, we see... (laughter) You see Dorian walk out of the acid facial room and he's, somet
# 	-  "Aye." (whistles) Begins to whistle and points upward, and you watch as the halfling begins to walk
# 	-  He gets behind you and-- not quite like making the vase in Ghost, but is trying to help show you ex
# 	-  I push him off, ten feet away from the group, and I pull out the same Keen Dagger–
# 	-  I get on my broom and continue the journey.
# 	-  And then Elatis is going to go ahead and glance over towards you, Caduceus.
#
#
# ==========================================================================================
#
#
# Cluster 23: 20925 / 935818
# 	-  Why are we doing this?
# 	-  There was an update that we probably--
# 	-  Whoa, time out, time out. We don't know where we're going yet, right? We have to find this thing.
# 	-  Oh hey, guys.
# 	-  This is an important thing we need to remember. As we're doing all this, let's just assume that we'
# 	-  Also, even though we totally sucked and let Vess die, proved my theory was right.
# 	-  You guys are feeling pretty good about your hats.
# 	-  Oh no, we did.
# 	-  We did not.
# 	-  We're in a fight.
#
#
# ==========================================================================================
#
#
# Cluster 24: 18484 / 935818
# 	-  I have it. It's--
# 	-  Are you a double agent?
# 	-  Do you still have a Mansion?
# 	-  Are there children's books in here?
# 	-  You've never had a rug in the river?
# 	-  Yes. We told them to send word to Allura, and to--
# 	-  Just now?
# 	-  Do I look like someone who gets her hair done often?
# 	-  Yeah. Can you do an arcana check on it?
# 	-  No, just the Traveler and I both believe in you, okay?
#
#
# ==========================================================================================
#
#
# Cluster 25: 21881 / 935818
# 	-  No good?
# 	-  Maybe mermaids rescued you.
# 	-  Do you need some breakfast or ale?
# 	-  So what have you been up to?
# 	-  Hello?
# 	-  Mm-hmm. Lots of relationships, but I never settled down. I like to roam the wilds free.
# 	-  I didn't get my phone call!
# 	-  So, as you think on it, the weeks pass–
# 	-  I'm not okay.
# 	-  I'm pretty hurt.
#
#
# ==========================================================================================
#
#
# Cluster 26: 21596 / 935818
# 	-  I was going to say, what was the number? Because that thing's got to have a low AC. What's the actu
# 	-  19 for mine as well.
# 	-  It's fine. No, it's not fine. That's better. 14.
# 	-  It's a 22.
# 	-  20!
# 	-  14, so I reduce that by 14.
# 	-  And a 16.
# 	-  That's good! 26.
# 	-  Ooh! Natural 19!
# 	-  Oh, wow. Two 17s.
#
#
# ==========================================================================================
#
#
# Cluster 27: 21501 / 935818
# 	-  I'll go back over to that soldier, unless that's the same person.
# 	-  Hey, watch where you're fucking--
# 	-  Oh no, you're getting shithoused during this round!
# 	-  I'm not going to pull it out. I'm going to push it through.
# 	-  Will you hate me if I do?
# 	-  Don't, none of us do anything. If we don't do anything for a minute, Tary's weak.
# 	-  Hey cat! Have you seen the kind of shit she can do? Oh look, your friend over there, he went ahead
# 	-  Wow, I'm sorry to intrude, but you're supposed to be the best hacker in all of the High Bear Nation
# 	-  Still holding back on your rage?
# 	-  Find out who wants to make out with somebody else! This is Dungeons & Dragons.(laughter)
#
#
# ==========================================================================================
#
#
# Cluster 28: 22156 / 935818
# 	-  I have dreamed about coming here since I was a little child. I'm going to see this!
# 	-  No no no! Don't go, don't go–
# 	-  Hopefully this is just a thing. We can just hang out in these places. It's nice.
# 	-  Am I leaving or am I staying?
# 	-  I'll stay with the two of you because I can't see shit and I'll slow you down. If things happen, th
# 	-  Yeah, sure. You all basically arrive at the same time.	Because that's convenient.
# 	-  I'm going to stay with Scanlan for a bit. Just for the night.
# 	-  Goodbye.
# 	-  Set sail. Towards the island!
# 	-  Yeah. After walking through just alone, I want to just go find a beach somewhere at night, and just
#
#
# ==========================================================================================
#
#
# Cluster 29: 16804 / 935818
# 	-  If you Alter Self, right?
# 	-  An unexpected arrangement of glowing sources across so many of the guests here. There are all manne
# 	-  And the Faerie Fire fades.
# 	-  Okay, okay, 11. It is challenging, because the two spells themselves seem to ouroboros for a moment
# 	-  Yeah. Because of your cloak.
# 	-  Oh, hold on, hold on. There are runes, of which I can read.
# 	-  Did I manage to catch with the Control Flame my entire Fire Breath when I did that? And I'm control
# 	-  Isn't your Mage Hand on the lever?
# 	-  Spirit Guardians, yes.
# 	-  This is going to get good! I mean, the more I learn, I'll share with you. Maybe if you learn, then
#
#
# ==========================================================================================
#
#
# Cluster 30: 20935 / 935818
# 	-  Not at its current position.
# 	-  We're going to want a rope.
# 	-  I mean if Avantika thinks it's okay. Does Captain Avantika think it's okay for us to take ten minut
# 	-  He'll be angry if he realizes we don't actually have anything, but at least he won't be able to tak
# 	-  I think we can only bring four people to the roof.
# 	-  What if we book a room, ask about the people we're looking for, and go from there?
# 	-  Maybe we can prepare the Feast, keep an eye out. If we have to ditch out on the Feast early, then w
# 	-  Do we want to do it now, or do we want to do it tomorrow night, is the question?
# 	-  I think so, too. We should just give it.
# 	-  Before we do, is there anything else that I saw popping up?
#
#
# ==========================================================================================
#
#
# Cluster 31: 13958 / 935818
# 	-  Fascinating. All right. That's my move.
# 	-  Maybe you should wait until we come across something.
# 	-  Hitting the two that I'm engaged with would be awesome.
# 	-  Go for it.
# 	-  Sure, go for it.
# 	-  Go for it. The patron looks at you-- growling, looks towards you and goes, "What?!" Surprise across
# 	-  It's up to you.
# 	-  -- of Message to do it, yeah.
# 	-  Does anyone that's very socially adept want to maybe--
# 	-  Okay. Do you know who you would prefer to start with?
#
#
# ==========================================================================================
#
#
# Cluster 32: 15236 / 935818
# 	-  Before it flew.
# 	-  Yeah, the cables have wrapped around the scaffolding that holds the mocap cameras, and trying to pu
# 	-  It looked at the moment like a creature that size could maybe squeeze through, but you also saw it
# 	-  Yeah. There's nothing left including the-- there's no circlet left behind.
# 	-  Grog will make wind.
# 	-  Yeah. It emerged and jack-in-the-boxed out towards you.
# 	-  Not super thick, but when you exhale you see a bit of the breath before you.
# 	-  Where's the extinguisher?
# 	-  It's flowing your direction.
# 	-  No, I wanted to fly down a little closer and see if I can see any footprints, and see where they le
#
#
# ==========================================================================================
#
#
# Cluster 33: 20544 / 935818
# 	-  “No, they're quite the opposite, actually.”
# 	-  "It costs quite a bit for the arcane, the skill set required to complete it. But that is what you h
# 	-  "Okay, okay."
# 	-  "If you could give us just a moment, please."
# 	-  “Uh…” He looks back and thinks to himself. “Not quite like this, though, but there are a number of
# 	-  "I don't know what that is."
# 	-  “All right. Greyskull Keep, you say?”
# 	-  “Do your friends speak Common?”
# 	-  “Very well, if it's an issue, then at least introduce me, and give me some sort of–  some sort of c
# 	-  "We can order some pickles, if you like."
#
#
# ==========================================================================================
#
#
# Cluster 34: 33952 / 935818
# 	-  Yeah, you.
# 	-  Listen.
# 	-  Neither am I.
# 	-  You did, that's true.
# 	-  Oh, that's true! (fake sobbing) That is my backstory!
# 	-  Not at all, dear.
# 	-  What do I do here? Okay, okay.
# 	-  Mm-hm.
# 	-  No, no, no, it's okay. It's okay, it's okay.
# 	-  What were you saying to our friend? Were you being nice?
#
#
# ==========================================================================================
#
#
# Cluster 35: 16465 / 935818
# 	-  Shove that dingleberry in there.
# 	-  Ugh! You were almost like ravioli stuffing.
# 	-  It's more than an expression, it's legitimately something you do. Unfortunately, you need salt for
# 	-  That's what happened.Oh, what is this?Is that cigarettes? TRAVIS
# 	-  I'm sipping it. I'm doing as the locals do. Enjoying it how he told me.
# 	-  And also some Greep for me.
# 	-  Oh, to make s'mores? That's a great idea.
# 	-  Crack! And then--
# 	-  A short time passes before the two platters are rushed over and scattered across the front of your
# 	-  The biscuit was very filling. It was extremely filling.
#
#
# ==========================================================================================
#
#
# Cluster 36: 7553 / 935818
# 	-  Oh boy.
# 	-  Oh no! Oh!
# 	-  Oh no!
# 	-  Oh no.
# 	-  Oh no!
# 	-  Oh yeah.
# 	-  Oh shit. (groaning)
# 	-  Oh no, don't.
# 	-  Oh no.
# 	-  Oh!
#
#
# ==========================================================================================
#
#
# Cluster 37: 8885 / 935818
# 	-  How deep is the pool?
# 	-  It's only a ten-foot radius.
# 	-  How far?
# 	-  I'll go 50 feet. Because that was my guesstimate for how far the ladies were from us when we were s
# 	-  Okay. So, 30 feet, Beauregard is definitely in that way. Yasha's definitely in there.
# 	-  Oh, yes, get ten feet back, I should've said that already.
# 	-  Fifteen feet up, yes, but you're also coming at an angle, which, you lose distance on that.
# 	-  I can use my tracking and my favored terrain to see how many within 6 miles, if there's a large gro
# 	-  How far is he from me? A long way.
# 	-  Flame Seed is 60 feet.
#
#
# ==========================================================================================
#
#
# Cluster 38: 18608 / 935818
# 	-  11. You take 36 points of necrotic damage from the enervation ray.
# 	-  Hit.
# 	-  All right, so go ahead and roll damage. It is a 1d4 plus your strength modifier.
# 	-  All right, that comes to 15d8 acid damage.
# 	-  That does hit, yes.
# 	-  No, when you roll a hit dice, you get hit points. That's during a short rest.
# 	-  You take 30 points of bludgeoning damage.
# 	-  Hits. When barbarians crit, man, things die. This is why relentless attack is so good with them. Th
# 	-  Dang it. Okay, 19 points of damage.
# 	-  That definitely hits.
#
#
# ==========================================================================================
#
#
# Cluster 39: 17223 / 935818
# 	-  In any of the spaces?
# 	-  Or you could just hang in Whitestone.
# 	-  All right, so under it, so right here.
# 	-  Um, okay, so, who's nearest?
# 	-  Well, if I were there.
# 	-  What was I at? I was at--
# 	-  I want to be near it, though.
# 	-  Well, you have a map.
# 	-  They're in Rexxentrum.
# 	-  You don't have to, there's mud baths.
#
#
# ==========================================================================================
#
#
# Cluster 40: 31040 / 935818
# 	-  Why wouldn't he be-- if he hired the soldiers that were in there?
# 	-  I don't think so, because I just heard him screaming.
# 	-  I was not in possession of the casket, as neither has been Mr. Merriweather.
# 	-  He healed us all up before we left, right?
# 	-  Great, he just said yes.
# 	-  Did any of his friends get out?
# 	-  Fitz is like, "I have to work! It's my livelihood!"
# 	-  I hope his secret weakness is ploughman's lunch or whatever. (laughs)
# 	-  I think Matt made that joke 12 years ago probably. Yes.
# 	-  But as Beauregard's talking, he's looking, he's looking--
#
#
# ==========================================================================================
#
#
# Cluster 41: 23871 / 935818
# 	-  Oh, fuck.
# 	-  Okay, okay, okay, okay.
# 	-  That is what I meant.
# 	-  Okay. That's it.
# 	-  Okay, cool.
# 	-  Oh, that's true. You're right.
# 	-  Oh, okay. I got to make a new page in my notebook.
# 	-  Oh, well, shit.
# 	-  All righty, so...
# 	-  Oh whew, thank god.
#
#
# ==========================================================================================
#
#
# Cluster 42: 9383 / 935818
# 	-  Make a deception check for me.
# 	-  Yeah, it was the tag. So I'm just checking it.
# 	-  Make an investigation check, each of you.
# 	-  It was an accident. There was nothing suspicious about it.
# 	-  I don't know who to trust anymore, to be totally honest.
# 	-  You could make an investigation check, if you'd like.
# 	-  We'll find out with this investigation check.
# 	-  Make a perception check if you want to go look.
# 	-  Make a deception check.
# 	-  Touch a few places to make sure it is physical and real.
#
#
# ==========================================================================================
#
#
# Cluster 43: 19664 / 935818
# 	-  I reach forward, throw that leg towards the right knee again. Still working on the same spot.
# 	-  Aim higher!
# 	-  You go ahead and dart down and find a pocket of the mountain where you can see enough snow has buil
# 	-  Yeah, sure. I want to earth glide underneath and pop up underneath of him.
# 	-  So you all climb down. Do you revert form?
# 	-  I take one leg to try and keep him calm and rub him. Stay calm, it's okay.
# 	-  As you move over, with that it comes to his turn. As you're moving to the side, he spins around thi
# 	-  You're nervous down there.
# 	-  And I'm going to use my movement to back away from it.
# 	-  All right. So do you all climb up onto J'mon's back?
#
#
# ==========================================================================================
#
#
# Cluster 44: 15364 / 935818
# 	-  I'm blind! It's very hot!
# 	-  They saw you.
# 	-  Yeah, it's depending on the weather whether you can see it or not.
# 	-  He can't see the dick drawings. They're hidden.
# 	-   It's hitting the hall, so there's a little bit of light coming through.
# 	-  I was seeing if we were in Gilmore's room, that's all.
# 	-  I was walking with Veth and Yasha at the back, and once we reach the pinnacle, I will cast Programm
# 	-  Yeah, yeah, yeah, I saw two glowing ember-looking eyeballs looking at me.
# 	-  Took me a minute to get there.
# 	-  Stealth!
#
#
# ==========================================================================================
#
#
# Cluster 45: 19003 / 935818
# 	-  (gasps)
# 	-  (gasps)
# 	-  (laughs)
# 	-  (squawking)
# 	-  (snarls)
# 	-  Yeah, it just like, (growls).
# 	-  (gasps)
# 	-  (groans)
# 	-  (singing Nokia ringtone) (laughter)
# 	-  It's a natural one.(laughter)
#
#
# ==========================================================================================
#
#
# Cluster 46: 20234 / 935818
# 	-  There you go.
# 	-  Let's go above them.
# 	-  I'll talk to Zeenoth.
# 	-  Let's do it, let's sleep.
# 	-  Yeah, it's fine. Let's just go.
# 	-  All righty.
# 	-  That works.
# 	-  Nott, you're up.
# 	-  I'll be last.
# 	-  I'm coming in.
#
#
# ==========================================================================================
#
#
# Cluster 47: 3634 / 935818
# 	-  Oh my god!
# 	-  Oh my god.
# 	-  Oh my god. This is immediate.
# 	-  Ugh!
# 	-  Oh god.
# 	-  Ugh!
# 	-  Oh god. I'm so scared.
# 	-  Oh my god.
# 	-  Oh my god.
# 	-  Oh my god.
#
#
# ==========================================================================================
#
#
# Cluster 48: 17288 / 935818
# 	-  Found a Twiggy!
# 	-  do the eyes in this picture bear any resemblance to the tattoos I spied through the window when I e
# 	-  Did I see any animals, or creatures, or monsters?
# 	-  What is one of them doing in a place like this? Can you believe it? (hiccup)
# 	-  The bats are a bit more potentially native to this area, aside from an orange, tawny cat.
# 	-  Yeah, it wasn't a guy with a cat hat. He was a demon.
# 	-  Are there any Vestiges of Divergence in the nest?
# 	-  I look at Caleb's giant albino and cream colored killer whale.
# 	-  You better hope that there's no flies about, then. That's a little mythology joke for you.
# 	-  This one was getting close, after the death unicorns, right?
#
#
# ==========================================================================================
#
#
# Cluster 49: 18920 / 935818
# 	-  It's just a thought, but I do have the big-ass jug that can make a big thing of portable water.
# 	-  But that's more for–
# 	-  Fuck up the thing in front of you, go get it.
# 	-  Then I don't do any of that. Instead, where's Scanlan?
# 	-  Keep your butt hole closed.
# 	-  Maybe you need to push it more. Maybe it's already closed.
# 	-  Make a survival check.
# 	-  With great power.
# 	-  Good to know for next time.
# 	-  Not going to make you do the one thing you're good at.
#
#
# ==========================================================================================
