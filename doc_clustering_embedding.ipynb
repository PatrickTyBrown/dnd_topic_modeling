# %% [markdown]
# # Document Clustering
# ### Using Embeddings

# %%
import json
import os
import random
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans

# %% [markdown]
# #### Define Parameters

# %%
n_clusters = 10 
n_samples = 10
n = 100
batch_size=64

# %% [markdown]
# ## Load Data

# %%
def create_df_multi(n=25):
    list_of_text = []
    dir = 'data/aligned data/c=4'

    files = [filename for filename in os.listdir(dir)]
    sampled_files = random.choices(files,k=n)

    for filename in sampled_files:
        # choice = random.choice(os.listdir(dir))
        # print(choice)
        f = open(dir+'/'+filename)
        data = json.load(f)
        choice = random.choice(os.listdir(dir))
        # print(choice)
        f = open(dir+'/'+choice)
        data = json.load(f)

        for x in data:
            for y in x['TURNS']:
                text = ' '.join(y['UTTERANCES'])

                # text = clean_text(text)
                list_of_text.append(text)
    # df = pd.DataFrame(list_of_text)
    return list_of_text

# %%
docs = create_df_multi(n)
df = pd.DataFrame(docs)
print(df.shape)
df.head()
# Out:
# (258748, 1)
#                                                    0
# 0  Hello everyone! Close. Welcome to tonight's ep...
# 1  Oh my gosh, all that crazy merch that we have!...
# 2               Hide your neighbors, hide your wife.
# 3  That's right. And we also have our Scanlan con...
# 4                                         Fantastic.

# %% [markdown]
# ## Embed Docs

# %% [markdown]
# - Load Embedding Model
# - Process Batches (May Take Awhile)

# %%
# model = SentenceTransformer('all-MiniLM-L6-v2')
model = SentenceTransformer('all-mpnet-base-v2')

embeddings = model.encode(docs, batch_size=batch_size, show_progress_bar=True)

print(embeddings[0].shape)
# Out:
# Batches:   0%|          | 0/4043 [00:00<?, ?it/s]
# (768,)

# %% [markdown]
# ### Save embeddings just in case

# %%
df['embeddings'] = embeddings[:].tolist()
df.to_csv('data/doc_embeds.csv')

# %% [markdown]
# ## Define Output Functions

# %%
def sample_clusters(labels, n_clusters = n_clusters, n_samples = 10):
    df['labels'] = labels
    for i in range(n_clusters):
        print(f'Cluster {i}: {len(df[df.labels == i])} / {len(df)}')
        sample = df[df.labels == i].sample(n_samples, replace=True)[0]
        for x in sample:
            print('\t- ' + x[:100])
        print('\n')
        print('==='*30)
        print('\n')

# %% [markdown]
# ## 5 Clusters

# %%
n_clusters = 5 
n_samples = 10

# %%
kmeans = KMeans(n_clusters = n_clusters, random_state= 42)
kmeans = kmeans.fit(embeddings)
sample_clusters(kmeans.labels_, n_clusters=n_clusters, n_samples=n_samples)
# Out:
# Cluster 0: 126127 / 258748
# 	- Dungeons and Dragons!
# 	- (blows nose)
# 	- That's typically how it works.
# 	- That is a good deal, sir, and I will give you the copper.
# 	- This one here?
# 	- We'll see each other, again, I hope. Grog.
# 	- Okay, so which do you want to know, of all the things that you can choose from?
# 	- Pulling this ripcord.
# 	- I didn't expect you to say that.
# 	- Oh snap! Shit's getting real.
#
#
# ==========================================================================================
#
#
# Cluster 1: 18941 / 258748
# 	- "He'll survive." And you can see now there's a look of pained anger in Uriel's eyes at seeing the fa
# 	- "To be fair Kima, in my experience and knowledge, ships function well for the movement of goods and
# 	- "Parts smoldering and left behind, the path continues over the Lucidian Ocean, eastward beyond the s
# 	- I don't say anything. (long pause)
# 	- "I don't know of the name 'The Gentleman,' but--"
# 	- "To his credit, the current Plank King has done a very fine job of maintaining organization in the R
# 	- He exits the building. Another five minutes pass, and eventually the woman comes back and she goes,
# 	- "Everyone out." And I start casting a Flaming Sphere.
# 	- Begins writing out an extended statement in the paper. Puts out to you and it says; "Family going we
# 	- "Yes?"
#
#
# ==========================================================================================
#
#
# Cluster 2: 19339 / 258748
# 	- Only a ten for me.
# 	- It actually rolled exactly a 13 with no modifiers, so it does succeed.
# 	- 37.
# 	- Eight plus five is 13. How many do I roll? Seven. Oh shit.
# 	- 24.
# 	- 15.
# 	- Negative two.
# 	- 20.
# 	- It's a nine!
# 	- Nine. Which is like a natural 20 in this campaign.
#
#
# ==========================================================================================
#
#
# Cluster 3: 75870 / 258748
# 	- Can I Detect Magic on any of them?
# 	- Can I roll stealth and hide right now? (laughter)
# 	- My spidey sense is tingling. It's behind us. It's over there. I used Locate Object.
# 	- You're watching her reaching out and grabbing this small sphere of sparkling energy. She grasps it,
# 	- Oh. Any time with mage slayer? Oh, that's right!
# 	- Are there any elements needed for this? Water, fire?
# 	- I'll inspire Percy. Just doing this move--
# 	- The sulfur represents the earth, the diamond represents the refraction of the moonlight, and the wat
# 	- Okay. I'm going to do something a little weird. I'm going to pull out Bad News. I know I can't shoot
# 	- So keep tabs on that because that will carry over into the next session. All right. So you guys are
#
#
# ==========================================================================================
#
#
# Cluster 4: 18471 / 258748
# 	- All right. [laughter]
# 	- Yeah.
# 	- Well.
# 	- Well.
# 	- No, it's not.
# 	- Yes.
# 	- Thank you.
# 	- Awesome.
# 	- Okay!
# 	- One of them, yeah.
#
#
# ==========================================================================================

# %% [markdown]
# ## 10 Clusters

# %%
n_clusters = 10 
n_samples = 10

# %%
kmeans = KMeans(n_clusters = n_clusters, random_state= 42)
kmeans = kmeans.fit(embeddings)
sample_clusters(kmeans.labels_, n_clusters=n_clusters, n_samples=n_samples)
# Out:
# Cluster 0: 126127 / 258748
# 	- Send him on his merry way.
# 	- (laughs)
# 	- Who's to say where he's going?
# 	- Can we get everybody else but Sam and Marisha to leave?
# 	- Do we have to get in disguise again in order to leave?
# 	- Two more editions of the art book!
# 	- Would you like to see the library?
# 	- I'm okay at surviving.
# 	- God damn it-- the chain devils. All right.
# 	- Percy, you are aware that here have been problems in the past with various mountain-faring giants th
#
#
# ==========================================================================================
#
#
# Cluster 1: 18941 / 258748
# 	- "Yes."
# 	- Hi. I step in after her. Yes, I've made some changes to the place. Living quarters are upstairs, the
# 	- "Dragons’ teeth actually, strangely enough, are a little easier to find. I would put, each dragon’s
# 	- "Do you have some?"
# 	- She gives a narrow look through her eyes, looks to one of the other guards that you can see standing
# 	- "Interesting. You seem to be struggling, Percy."
# 	- "Yes, I am a skilled swordsman!"
# 	- "Now, we've had a few weeks of peace and recovery, of rebuilding and reforging the real bonds of thi
# 	- All the rest of the crownsguard glance to each other, he goes, "Well, unfortunately, that is not for
# 	- "You may be innocent, in which case you have nothing to worry about. However, we have an investigati
#
#
# ==========================================================================================
#
#
# Cluster 2: 19339 / 258748
# 	- Slice number one. Oh, for fuck's sake. Ten.
# 	- Eight points.
# 	- 13.
# 	- So two, but roll the d6, which is also doubled.
# 	- Three. (laughter)
# 	- That is going to be a 24 to hit.
# 	- Did you get a 20, did you get a 20 on it?
# 	- One of 17.
# 	- That's a 17 to hit. What's your armor class?
# 	- 14 misses.
#
#
# ==========================================================================================
#
#
# Cluster 3: 75870 / 258748
# 	- Nothing happens.
# 	- It does do sneak attack damage, because you guys are in the vicinity.
# 	- You're on an angle there, on each side.
# 	- Oh I know, I came in here to tell you, to ask you something: where's my wand? (laughter)
# 	- Give the invulnerability to Laura.
# 	- It'll wake us up. So who's guarding Caleb?
# 	- It's an incubator. This isn't a coffin. It hatched.
# 	- Vax, double-check the gold floor, I'm not--
# 	- He's bloodied. He's definitely bloodied.
# 	- Perception check.
#
#
# ==========================================================================================
#
#
# Cluster 4: 18471 / 258748
# 	- All right.
# 	- Sure.
# 	- Okay.
# 	- Got you. Yeah.
# 	- Yes.
# 	- Okay.
# 	- Yeah.
# 	- Ish.
# 	- Anyway.
# 	- Okay.
#
#
# ==========================================================================================

# %% [markdown]
# ## 20 Clusters

# %%
n_clusters = 20 
n_samples = 10

# %%
kmeans = KMeans(n_clusters = n_clusters, random_state= 42)
kmeans = kmeans.fit(embeddings)
sample_clusters(kmeans.labels_, n_clusters=n_clusters, n_samples=n_samples)
# Out:
# Cluster 0: 14354 / 258748
# 	- By the way, guys, this finally came in today.
# 	- It's pretty awesome, we're excited.
# 	- That's amazing.
# 	- How's the weather; is it clear or grey?
# 	- These horns will be yours. and definitely go follow Kai on Instagram and on Facebook and definitely
# 	- It's just the two of them at the moment.
# 	- I feel like I can do so much more. (phone rings)
# 	- Thank you both.
# 	- And during that whole exchange, I've been changing cloaks and putting on the red one. Great.
# 	- Kima is very happy.
#
#
# ==========================================================================================
#
#
# Cluster 1: 15861 / 258748
# 	- It would take you about an hour or so to do so. To a studied physician, probably not going to hold u
# 	- Okay, I'm going to do what I originally planned which is to make the hole not look like a perfect ho
# 	- I don't know. I've never done it before.
# 	- No, you do not.
# 	- Yes, of course.
# 	- I can do this for the future.
# 	- Hey, you can get the note.
# 	- I mean, you can. The progress will slow a bit because you're now taking it through the hills and the
# 	- Either way, we can now ask about the ritual.
# 	- Make a nature check.
#
#
# ==========================================================================================
#
#
# Cluster 2: 11169 / 258748
# 	- Two 20s. 19 to 15?
# 	- Let's see. 13.
# 	- Wait, 19 extra?
# 	- I already added that, we’re at 20,000.
# 	- A six and-- oh, no advantage? I'll take that six with my add perception of three, so nine.
# 	- Currently five--
# 	- 17. Couple of things you notice. One  you glance in the vicinity, you look and notice the Plank King
# 	- Yeah, it's 15. No, it's not good, no.
# 	- Each of them. Do I roll that?
# 	- And then six because this is doubled.
#
#
# ==========================================================================================
#
#
# Cluster 3: 16560 / 258748
# 	- And I can be in the back and be drunk and lookout.
# 	- I have to go to the water ashari. I have to.
# 	- You're going to get the weasel too, okay. Here's my question: what do we do with all these animals?
# 	- From where you are to the-- make a survival check.
# 	- I'm going to rush forward and help. Do the same thing.
# 	- I'm keeping watch on the right.
# 	- I guess I will be falling back because I'm going to talk to him.
# 	- Okay. You head back out onto the street. You are in that chamber for a while. Are you doing anything
# 	- I mean, we could catch brunch first?
# 	- She's saying a ship will be ready in two days or take two days to travel?
#
#
# ==========================================================================================
#
#
# Cluster 4: 15574 / 258748
# 	- I'm going to see if I can climb the tree and get to it.
# 	- You progress down through the ritual area, carefully avoiding a scattering of metallic ball bearings
# 	- Yes. It is now a safety hazard.
# 	- Traps, or people hiding?
# 	- That looked bad from this angle. Yeah, I see it now! Holy cow.
# 	- It's a low-life area.
# 	- The gate's about eight feet tall and the building is three stories. So I mean there are some roof-ed
# 	- Yeah, that is bad news. Are the carts all heading in the same direction or would they split up?
# 	- But wait. Before we go, is there anyone walking about the docks? You know, like dockhands?
# 	- Ten feet away.
#
#
# ==========================================================================================
#
#
# Cluster 5: 4567 / 258748
# 	- 24.
# 	- 23.
# 	- 11.
# 	- 24? All right.
# 	- 16.
# 	- 16.
# 	- 17.
# 	- 19.
# 	- Oh yeah. 14.
# 	- 16.
#
#
# ==========================================================================================
#
#
# Cluster 6: 6469 / 258748
# 	- Yes.
# 	- Yeah.
# 	- Yep.
# 	- Yeah.
# 	- Yeah?
# 	- Absolutely.
# 	- Yes.
# 	- Yep.
# 	- Yeah, yeah.
# 	- Yeah.
#
#
# ==========================================================================================
#
#
# Cluster 7: 8129 / 258748
# 	- How many hit points?
# 	- Natural 17. It resists the stun, I'm sorry. But it's doing damage to it. As you slam into it again,
# 	- Next strike. That definitely hit. That's 24.
# 	- 19 does not hit, unfortunately.
# 	- Second attack.
# 	- 62 hit points.
# 	- All right, the attack against you, Scanlan. That is gonna be a 17 versus AC. All right, this one is
# 	- So you take 11 points of piercing damage as all of a sudden, Trinket sinks his jaws into the back of
# 	- And then any additional damage would go over into your--
# 	- Trinket takes nine points of bludgeoning damage from the staff.
#
#
# ==========================================================================================
#
#
# Cluster 8: 14749 / 258748
# 	- You can. You can't combine different abilities that spend grit points, but you can combine Sharpshoo
# 	- So, he can cast two spells; they have to be at third level.
# 	- Sacred Flame, save. You said dex?
# 	- Do you have to attune to them?
# 	- Disadvantage because I'm poisoned. 18.
# 	- He has one last legendary resistance.
# 	- With advantage.
# 	- You use this bardic inspiration specifically for stuff like this.
# 	- It's going to use Incite Rampage.
# 	- Make a strength check.
#
#
# ==========================================================================================
#
#
# Cluster 9: 8332 / 258748
# 	- She doesn't know about J'mon Sa Ord.
# 	- She pushes her glasses up and looks vastly unimpressed at the presentation.
# 	- She leads you across, she goes,
# 	- Oh, Dashilla.
# 	- So she said she was selling it, and I said, "Wouldn't that draw attention to the tavern, though?" an
# 	- I just saw Jester open her purse. Dear--!
# 	- Did she say anything else about what she wants?
# 	- Sorry. Her brain. That's what I'm talking about.
# 	- Scratch her up.
# 	- Oh, is it because she's a murderer?
#
#
# ==========================================================================================
#
#
# Cluster 10: 14246 / 258748
# 	- Please be careful. Wait, I tell him. Scanlan, this is very delicate. Please be very gentle with this
# 	- I was thinking to myself it was either going to be that or some grim reaper's going to show up and c
# 	- Here’s the thing. He’s not a joke-telling kind of comedian. He’s more of a farce kind of comedian. P
# 	- Percy is just perfectly reasonable.
# 	- Lionel.
# 	- The mind flayer isn't on pause!
# 	- 120 feet? He's out of range.
# 	- Yeah, he did
# 	- I think I called him U-tu-gash, because that's what I wrote down.
# 	- Was his name Frederick? No, it was with an 'r'.
#
#
# ==========================================================================================
#
#
# Cluster 11: 4746 / 258748
# 	- All right.
# 	- Okay.
# 	- Sure.
# 	- Okay.
# 	- Well, all right.
# 	- Okay.
# 	- Yeah, okay.
# 	- Okay.
# 	- Yeah, I'm all right.
# 	- Okay.
#
#
# ==========================================================================================
#
#
# Cluster 12: 13794 / 258748
# 	- I tighten the grasp on them.
# 	- Slip by the back, yeah.
# 	- It closes.
# 	- The fleshy bit is on the opposite side, by the way. So you're now at an unarmored side. However, it'
# 	- Following your partner.
# 	- Actually, you didn't have to make it because you're walking.
# 	- And I get all my grit back.
# 	- I put it on the floor and I snap him into existence. There you go, buddy.
# 	- What if it explodes the lock and then we're not able to get in at all?
# 	- I whistle at Trinket to get him to stop.
#
#
# ==========================================================================================
#
#
# Cluster 13: 14901 / 258748
# 	- She pulls another dark cloak off the wall. This one looks like it’s made of dark fur, but as she sha
# 	- Well first I drag Keyleth off to the cozy little bathtubs that they have here in the castle and took
# 	- The mouths are closed. You take the Quall--
# 	- From what you can tell, the meal that was prepared, the pots and pans and stuff that were used to co
# 	- Percy. The string's leaving a mark in my chin and cheeks. I feel like now is a good time to put the
# 	- "Astra, free treats!" And they start grabbing and filling their pockets with blondies and eating the
# 	- That was my bonus action. For my action, I will tell the two goblins--
# 	- Are you saying that Keyleth and I are caught up, at this point? Because I know that people started g
# 	- She leads you up the stairway to the second floor. The second floor itself is just a series of glass
# 	- So. You guys, utilizing your stealth checks and the Seeming, you make your way up to the-- which sid
#
#
# ==========================================================================================
#
#
# Cluster 14: 23954 / 258748
# 	- Did not care about your buttons.
# 	- You have wet dreams, you have wet dreams, too!
# 	- Kiki, don't kill yourself over this rock!
# 	- Yeah, I slept really hard.
# 	- Who are you?
# 	- Yeah, like a lot.
# 	- I will never, ever outlive the shame I feel for inventing these. I put it back down. Walk away.
# 	- The farting does keep you warm, Vax.
# 	- You suck, Ripley!
# 	- Have you never had a whisper?
#
#
# ==========================================================================================
#
#
# Cluster 15: 6142 / 258748
# 	- (laughs) Every time.
# 	- (laughs) Take the dark purple, moody one! Or I should have given you a different one.
# 	- I like it. (laughter)
# 	- Give me the jacket back. (punching) TALIESIN You earned that jacket.
# 	- (as Nott) All right! I'm done! Hand me that dead cat!
# 	- (terrified laughter) Oh my god!
# 	- Here we go. (funny accent) See, this comes in handy more often than you'd think.
# 	- (huffs) True. (laughter)
# 	- What a beautiful tree you've found. It casts so much shade. (laughter)
# 	- I'm the new guy. (all laugh)
#
#
# ==========================================================================================
#
#
# Cluster 16: 15694 / 258748
# 	- Shocking as that is.
# 	- That's what I've heard.
# 	- Exactly.
# 	- That's cool.
# 	- Ugh, yeah.
# 	- What?
# 	- I know.
# 	- Wait.
# 	- That's unbelievable.
# 	- Knew that much.
#
#
# ==========================================================================================
#
#
# Cluster 17: 15680 / 258748
# 	- We could get the one in the back, and then the other two might look at him.
# 	- In here, we're Lucien.
# 	- I remember saying that we should hide the corpses and Cali actually said, "Don't do it, there's no p
# 	- We're pretty cool.
# 	- Shit balls ass! Let's do it.
# 	- This one right there in the front, it's going to make-- let's see here.
# 	- No time like the present.
# 	- I mean, maybe we should return to something like sabotaging the machine, or... burning the city. Oh
# 	- I think we start moving in that direction and when nightfall comes we make camp.
# 	- Let's make this happen.
#
#
# ==========================================================================================
#
#
# Cluster 18: 11607 / 258748
# 	- "It was delightful. You travel with the finest companion. We told stories, we cried, we laughed. It
# 	- "I do, actually, I'm quite the appraiser. It's part of my business."
# 	- "It's all right. I will speak for this group as you also know of their exploits and their abilities.
# 	- "Do you know the purpose of this item?"
# 	- "You bad people?"
# 	- "I appreciate that. I say the same to your team. That was no small feat. I mean, literally. It was v
# 	- "Should I be mean?"
# 	- "Sure."
# 	- "At the moment, no. At the moment I'm a civilian, and a drunkard."
# 	- The crownsguard to the left of you goes, "You should listen to her. Those bedpans are pretty terribl
#
#
# ==========================================================================================
#
#
# Cluster 19: 22220 / 258748
# 	- What is that?
# 	- That’s it?
# 	- Do they have any?
# 	- Is there anything in the sails? Any flags, iconography?
# 	- The thing that he killed the old lady with.
# 	- And bear claws.
# 	- (like Beau) "Where do babies come from?"
# 	- Yes. Well, no, I was going to say compost. There you go, compost was the word I was looking for.
# 	- Scanlan Shorthalt, playing Vegas, ladies and gentlemen.
# 	- What's your AC there, big guy?
#
#
# ==========================================================================================

# %%
## 50 Clusters

# %%
n_clusters = 50 
n_samples = 10

# %%
kmeans = KMeans(n_clusters = n_clusters, random_state= 42)
kmeans = kmeans.fit(embeddings)
sample_clusters(kmeans.labels_, n_clusters=n_clusters, n_samples=n_samples)
# Out:
# Cluster 0: 4754 / 258748
# 	- I've already thought about it.
# 	- Go for it.
# 	- You could. But I know these two.
# 	- You have no choice?
# 	- I'm going to jack it up and see if I can--
# 	- I did!
# 	- You can go around this one there.
# 	- Once a year, I can do that. It takes a year to rest.
# 	- I don't know. I mean, like, I kind of want to. I mean, so like. Like bad things.
# 	- Yes, you can. Make a stealth check.
#
#
# ==========================================================================================
#
#
# Cluster 1: 7041 / 258748
# 	- I have a platinum bracelet which I assumed was just fancy and pretty. Here, look at that one too, Pe
# 	- I was going to put it on that leather.
# 	- The biggest one's a bit--
# 	- Each page is a centimeter thick, though, on this book.
# 	- That's Travis's!
# 	- Currently, it looks like there was another sheet that looks like most has been torn off. The rest of
# 	- Gotcha. Hey, Miss Jester? Apparently you picked something up in Zadash-- I'm supposed to see the thi
# 	- I've also carved, in Elven, in the inside, "Kick Me."
# 	- Sinew.
# 	- It's big?
#
#
# ==========================================================================================
#
#
# Cluster 2: 3628 / 258748
# 	- It's just two. It's shank shank.
# 	- I'm going to do it at 3rd level, so that's four, 6d6.
# 	- That's a hundred.
# 	- That's a half hour is a short rest. Or an hour is a short rest.
# 	- My wisdom modifier, I believe it's three.
# 	- That hits. How many Luck have you used, by the way?
# 	- We’ve got three.
# 	- 18 times two, 46. Plus one.
# 	- It's a lot!
# 	- Damn. That's half.
#
#
# ==========================================================================================
#
#
# Cluster 3: 7384 / 258748
# 	- Would you mind, I don't want to go in, but would you mind if I tagged along with you?
# 	- Probably. Know what? I'm going to stay because I don't know what my fucking speed is because I'm pan
# 	- Yeah. Okay. So this wrecked me. So here's what we're going to do. I'm going to send you guys on your
# 	- All right, all right, all right, all right. Let's go really fast. There's dragons in the world, we d
# 	- I'm going to run over to my sister.
# 	- So you two make your way--
# 	- Yeah, I'll hang down.
# 	- I'll turn around and go the other way.
# 	- You didn't bring your stuff?
# 	- Tiberius-- I don't know. But I want us to be as safe as we can. Tiberius, can you lift us up on your
#
#
# ==========================================================================================
#
#
# Cluster 4: 2000 / 258748
# 	- It's hard to pick. I don't know. I have a soft spot for Grog.
# 	- Grog, what are you doing? This is our kitchen and we need to eat dinner here!
# 	- Grog, your beard might go away.
# 	- That's Grog taint.
# 	- We should go watch Grog fight.
# 	- Grog will believe whatever you say.
# 	- Touché, Grog.
# 	- All right, that ends their turn. Grog, you're up.
# 	- Grog was easy, he makes bad decisions, which is just all that I do.
# 	- Grog, though you are having a hard time coming to terms with it, in the back of your head there's a
#
#
# ==========================================================================================
#
#
# Cluster 5: 2801 / 258748
# 	- First roll of the campaign.
# 	- Missed. Rolled a nine.
# 	- So he rolled stealth.
# 	- I mean, I'm invisible, and I rolled a five.
# 	- I rolled low.
# 	- 2d4, I think I roll it.
# 	- My rolls were better!
# 	- Do I need to roll again?
# 	- What am I rolling?
# 	- Wait, did you roll a 20 and an eight?
#
#
# ==========================================================================================
#
#
# Cluster 6: 4811 / 258748
# 	- Natural 20.
# 	- 18 to a natural one. (shouting)
# 	- 16 is the DC! All right. For that ogre over there, that's a failure. He's going to be slow.
# 	- Eagle eyes. 27.
# 	- 13 plus five. 18!
# 	- Let me find a d20. Oh, ten.
# 	- Yes! 28 and 27.
# 	- (strained) That's pretty good. That's a 30, minus five is 25.
# 	- Yeah. Third one is 19.
# 	- It's just a plus two? Oh, wait. Wrong guy! Ooh, 19.
#
#
# ==========================================================================================
#
#
# Cluster 7: 6329 / 258748
# 	- I'm going to go over and backhand his face.
# 	- Okay, so your second attack is going to be to try and grab his ears. Go for it.
# 	- Just hit each other!
# 	- But you're a badass rogue!
# 	- Does that finish your turn, Yasha?
# 	- No, kill the kraken.
# 	- I'm back in security guard mode.
# 	- I am the greatest rogue alive! I will go try and disarm that trap. Well, with my Mage Hand.
# 	- Yeah, because that's my action.
# 	- I pop Trinket out and I heal him.
#
#
# ==========================================================================================
#
#
# Cluster 8: 9335 / 258748
# 	- Whoa, the audience turned.
# 	- My title.
# 	- Persuasion six, deception two.
# 	- Just like that.
# 	- Taking the piss.
# 	- And it's always gone right.
# 	- But then what?
# 	- Up close and personal.
# 	- Reckless.
# 	- Les Mis was a stepping stone for that moment.
#
#
# ==========================================================================================
#
#
# Cluster 9: 6252 / 258748
# 	- I sit down next to Waldok with another drink and hand him a drink.
# 	- In the midst of the chaos you see a young man in his late teens or so with a little bit of a prickly
# 	- Pulls up his shirt and dabs at his mouth. It barely touches any of the actual food that's around his
# 	- He just glares at you.
# 	- He runs up the side. (impacts) He glances down, looking towards where you are. All right, that's goi
# 	- So Sherri looks at the rest of you as they leave and goes,
# 	- As you both bow, and you say this phrase, you watch as Johann and Astra, they bow low as well.
# 	- The Sovereign gives you a look and says,
# 	- Well, he got scared by the cat! The first guy was a dick, this guy was (yells), like kicking wildly.
# 	- And he leans forward and goes, "This here is the Change-Bringer's Nectar. You sip this, slowly."
#
#
# ==========================================================================================
#
#
# Cluster 10: 6397 / 258748
# 	- We need half a pound.
# 	- Then they get here, "Oh, crack!" Or maybe we stop them first, crash, stop, everything stops, then we
# 	- (groans) That still seems extreme. We should just book it.
# 	- Well, maybe if we cause enough of a ruckus as soon as we release him.
# 	- We could go ask.
# 	- That's my favorite mindset.
# 	- There might be a chance.
# 	- We wouldn't have to kill the horse, we could just send the horse--
# 	- It's really shallow. Shouldn't we weigh them down with something?
# 	- Immortalize our shitheadedness, that'd be good.
#
#
# ==========================================================================================
#
#
# Cluster 11: 5567 / 258748
# 	- Advantage!
# 	- Wait, can I use Uncanny Dodge again because it's gone around?
# 	- Well, as your action you can just go into it without having to spend a ki point.
# 	- Wait, he gets a full action and his companion animal gets to attack?
# 	- They do. Your foot being wounded, though, is a disadvantage right now.
# 	- Can I learn its lowest saving throw ability?
# 	- That changed the game forever.
# 	- It's a reaction. It doesn't say, I can make an attempt to catch.
# 	- And see what happens. Moonbeam. So a shapechanger makes its saving throw with disadvantage, and if i
# 	- Plus your rage damage.
#
#
# ==========================================================================================
#
#
# Cluster 12: 4414 / 258748
# 	- Critters, we love you. Thanks for watching the show.
# 	- In it cool news, tabletop columnist, offering to DM a game for me. I may have to hit you up on that
# 	- Real talk with Zac. But thank you guys so much for doing this. The subscribers really wanted to do i
# 	- Matt, I also have to throw out. We on Skype now get the full Twitch view, so I'm seeing you guys wit
# 	- Oh man. Good game. Mark, thank you for coming on!
# 	- And welcome back. I remember writing the script for that and going, "We're going to have to cut all
# 	- So welcome, Travis and all of you guys. Before we jump into tonight's game, let's get through some a
# 	- Thank you, Sam and Ashley, and thank you our friends at D&D Beyond. And thank you Hamilton for hopef
# 	- And he's got a youtube channel, Mars Rising, which is great. And I did a Splinter Cell guards sketch
# 	- They still haven't heard my favorite voice from this campaign yet. 'Cause we haven't gone back to th
#
#
# ==========================================================================================
#
#
# Cluster 13: 4718 / 258748
# 	- (confused chirping)
# 	- (shouting) Yeah!
# 	- (laughs)
# 	- Those are the only options there? [laughter]
# 	- (hums) I hum back at it.
# 	- (laugh)
# 	- (groans) I'm so mad!
# 	- Well, I'm glad we got that cleared up. (laughter)
# 	- (kiss) (laughter)
# 	- [no audio]
#
#
# ==========================================================================================
#
#
# Cluster 14: 7023 / 258748
# 	- Gohan, what happens when Uncle Ogden has too much, you know, (drinking sound).
# 	- Little Leatherface.
# 	- The other Ashly.
# 	- I guess I go back to Caleb.
# 	- Then, there's this Sorris fellow. I don't know, he didn't seem like he's be a font of any knowledge.
# 	- (hoarsely) Victor. (laughter)
# 	- (singing off-key) "All the sailors say Brandy, you're a fine girl. What a good wife you could be."
# 	- Thaign. (cheering)
# 	- Ermahgerd.
# 	- Not Thorbir, he's great.
#
#
# ==========================================================================================
#
#
# Cluster 15: 5690 / 258748
# 	- The lightning and the psychic didn't do anything?
# 	- A simulacrum can not be healed, except by--
# 	- Maybe this yellow vial of potion could do something for it as well.
# 	- Well, I can cast Pass Without A Trace on myself, and as long as we hug close to me, there's an area
# 	- I'm just saying, you got to buy your spell components.
# 	- Can I make a suggestion, Febron? And I cast Suggestion on Febron.
# 	- To give you specifics, it requires attunement by a paladin.
# 	- Bring that fucking wizard down here with you.
# 	- Should I cast Good and Evil Detection again?
# 	- Yes. I want to cast Pass Without a Trace on everyone.
#
#
# ==========================================================================================
#
#
# Cluster 16: 1974 / 258748
# 	- Yes.
# 	- No.
# 	- Yes.
# 	- No.
# 	- Nope.
# 	- Yes.
# 	- Yes.
# 	- No.
# 	- Yes.
# 	- No.
#
#
# ==========================================================================================
#
#
# Cluster 17: 2862 / 258748
# 	- Great.
# 	- Okay.
# 	- Okay.
# 	- Okay.
# 	- Okay.
# 	- Okay.
# 	- Okay.
# 	- Okay.
# 	- Okay.
# 	- Okay.
#
#
# ==========================================================================================
#
#
# Cluster 18: 4669 / 258748
# 	- Do you perhaps see the thing beneath the city?
# 	- Then this is a stealth mission.
# 	- Darling, something magical is happening. Our boy, the magical light that will illuminate the univers
# 	- Not a mirror image, not one blue one green?
# 	- Okay. (whoosh) As you release it, it's still a good distance. It (whoosh) continues through. As you
# 	- That's all right. You're welcome. I was sure it was here. I traced it. I followed them. I knew that
# 	- Right now, somewhere, there's a man on an airship going, "Do you see it yet?"
# 	- I don't know. You ever see something you felt like you'd seen in a dream before, but you don't know
# 	- Okay, as you pull the cloth up and look, the grey light energy spills out from underneath, and you w
# 	- Yeah, there's no light on the ship.
#
#
# ==========================================================================================
#
#
# Cluster 19: 2213 / 258748
# 	- That's fine.
# 	- All right, then.
# 	- All right. So.
# 	- Thank you.
# 	- That's fine.
# 	- That's fine.
# 	- That's fine.
# 	- All righty, so.
# 	- All righty. [groaning]
# 	- All right.
#
#
# ==========================================================================================
#
#
# Cluster 20: 6370 / 258748
# 	- Wonderful.
# 	- You're so good.
# 	- Badass.
# 	- Fuck yeah.
# 	- And with that, I do Inspiring Leader, my newest feat since I'm a leader. (laughter)
# 	- A pleasure doing business with you. This haircut might very well be the fate of the world, so thank
# 	- That's pretty cool, yeah.
# 	- Wow, this is an amazing--
# 	- Oh, that's amazing. Cool. Perfect.
# 	- I feel really inspired.
#
#
# ==========================================================================================
#
#
# Cluster 21: 3586 / 258748
# 	- I have a little bit left over. I gave her a third of a barrel worth, like twice this.
# 	- You do have 1,000 ball bearings, I remember that. We had money. She bought a lot of fucking ball bea
# 	- I have a feeling it's an offering.
# 	- No, wait, hold on. (counting) So it's 140, so it is 70 gold each.
# 	- I swallowed the coin.
# 	- "6,500 gold pieces for the lot, with the discount."
# 	- How much do we have? He does have a picture of it. We have 1,620 platinum.
# 	- I might get some residuals.
# 	- I know. All right. They meet your raise. That's now 21 gold, I believe, on the table, so you all get
# 	- Everything just changed. How much did you get?
#
#
# ==========================================================================================
#
#
# Cluster 22: 2368 / 258748
# 	- Maybe we should try-- Does anybody have any healing? I know Pike isn't here, but--
# 	- I walk away a little bit from Fjord.
# 	- That's true, look at Pike's grandpa.
# 	- He's currently being held by Yasha and looking right over at Fjord, who's backed away, hands up.
# 	- Pike!
# 	- One more thing, just so they know we're following through. We have the picture for you guys to sign.
# 	- Sure, that makes sense. Pikey-poo, where are you going?
# 	- All right. I'll be part of the Fjord expedition. (laughter and groaning)
# 	- That ends Beau's turn. Fjord, what are you doing?
# 	- I turn to Fjord and I go, I'm not a claque, this show's bullshit.
#
#
# ==========================================================================================
#
#
# Cluster 23: 6150 / 258748
# 	- You could break your tooth.
# 	- You can't tell if the sour smell is intentional flavor or just time taking its toll. It'll be tart o
# 	- I was thinking if we had a small glass jar of it, we could give it a throw.
# 	- We can get you a prosthetic little toe that has a little compartment for poison.
# 	- Can I toss it into the well?
# 	- I come over to my sister with two big mugs of ale and hand one to her and say, here, don't swallow t
# 	- I don't-- I don't think you're supposed to eat-- that's creative.
# 	- I take a big old sip.
# 	- I was distracted. I was thinking about my books. I don't want them to get harmed. Your bag is probab
# 	- That's why I have my tiki mug today.
#
#
# ==========================================================================================
#
#
# Cluster 24: 11518 / 258748
# 	- Shut up.
# 	- That hurt.
# 	- I'm so sorry.
# 	- I want to be.
# 	- Come on, you tall, magical cow.
# 	- No, I kind of fucking like it, actually.
# 	- It's shit, man. You gotta choose a new--
# 	- This is so stupid.
# 	- No, I'm just giving you a hug!
# 	- It's just you, Taliesin.
#
#
# ==========================================================================================
#
#
# Cluster 25: 1870 / 258748
# 	- Yeah, a hit point or two.
# 	- First hit was 37.
# 	- Oh, it hits!
# 	- It misses?
# 	- Never had a rock really hit back.
# 	- That hits.
# 	- Hits.
# 	- They're both 15, so that's a 23 to hit.
# 	- You can hit them both.
# 	- Second one hits.
#
#
# ==========================================================================================
#
#
# Cluster 26: 6701 / 258748
# 	- We do our best.
# 	- No one now, but in the future-- it's a frequent occurrence for us.
# 	- Oh no, we missed our stuff.
# 	- Yeah, we are. Because when we write the name down, it's actually the Zemnian word for no. So even if
# 	- So we're all up there now?
# 	- We knew we were going to the blacksmith.
# 	- We do really good things most of the time, though.
# 	- No, we did very well.
# 	- We're trying to shoot for here?
# 	- We will.
#
#
# ==========================================================================================
#
#
# Cluster 27: 7058 / 258748
# 	- What?
# 	- I know.
# 	- Okay, cool.
# 	- I’m going to keep that.
# 	- That's not good.
# 	- Oh.
# 	- Okay. Good to know.
# 	- Oh, cool.
# 	- Yeah. That's--
# 	- There you go.
#
#
# ==========================================================================================
#
#
# Cluster 28: 5424 / 258748
# 	- Sharks don't die as soon as they get out of the water. You can last a couple minutes out of the wate
# 	- Ah. They do-si-doed?
# 	- Well, they know we're here now.
# 	- Fencing them.
# 	- I just thought maybe they knew each other.
# 	- And then they had that hired hand with them.
# 	- Tary, dear. Darling. They don't treat her very well, and they'll use her, and they'll stay here and
# 	- Follow them.
# 	- Right. Well this isn't a perception check, this is to make their way through the swamp to keep track
# 	- The dogs. Shit and piss everywhere. I know you were in our room.
#
#
# ==========================================================================================
#
#
# Cluster 29: 7491 / 258748
# 	- Probably.
# 	- Absolutely not. None of them are.
# 	- Nope. Fires off in the distant cloud.
# 	- Yep, I saw it.
# 	- No, why?
# 	- Envisioned it?
# 	- Yes, that's my thought.
# 	- It might.
# 	- Is the stream down by the way?
# 	- It is.
#
#
# ==========================================================================================
#
#
# Cluster 30: 3526 / 258748
# 	- Oh no!
# 	- Oh, shit.
# 	- Whoa.
# 	- Ooh.
# 	- Ouch.
# 	- Oh, man.
# 	- Oh jeez.
# 	- Whoa!
# 	- Fuck.
# 	- Aw.
#
#
# ==========================================================================================
#
#
# Cluster 31: 5633 / 258748
# 	- Oh, I'm not looking for anything, I just--
# 	- I can do that now.
# 	- That's great. You know what? I have something I think that you would be deeply interested in, maybe.
# 	- I've got one on hand right now, beotches.
# 	- I would like to take a look into it if possible, and see if it makes sense. I am a builder.
# 	- We can Skype you in.
# 	- All right. And Vax?
# 	- I can be on the roofs nearby along with Vex and Percy doing range.
# 	- Can I have a gull?
# 	- We'll get to that in a second. Vex. Vax, sorry.
#
#
# ==========================================================================================
#
#
# Cluster 32: 9707 / 258748
# 	- "I've already given you too much. Let me go amongst my pride swallowing."
# 	- "No, I'm just taken."
# 	- "If you're hungry, there are plenty of fruits that have dropped from the trees on the island. First
# 	- "Thank you." He pats you on the head with his nub.
# 	- "She's been singing with us for over two years, now."
# 	- "They have members from all across the world. We'll see which resources they have at their disposal.
# 	- "I understand."
# 	- "Before the River's Dawn! That one, yes. It was a continuation of the creation myth of Wildmount, bu
# 	- "That's certainly not the first time I've heard that!"
# 	- "What line of credit?"
#
#
# ==========================================================================================
#
#
# Cluster 33: 8830 / 258748
# 	- Well, he does all of them and then divides.
# 	- Watch him while he sleeps.
# 	- He didn't see it being cast. He withdrew before it happened, so he steps right into it.
# 	- I think he's in jail, isn't he?
# 	- "Had it not been for Gilmore’s Glorious Goods." (all laugh)
# 	- I think it's like his focus, you know?
# 	- Is he awake still or does he--
# 	- We're over his family's keep?
# 	- But now he's in love.
# 	- Yeah. Just half-cousin. Talks kind of like him, too, it's really creepy.
#
#
# ==========================================================================================
#
#
# Cluster 34: 2718 / 258748
# 	- It's six, so--
# 	- I got ten.
# 	- It's eight plus two, which is your proficiency bonus, which is ten. Plus your wisdom modifier. What
# 	- Okay, I will unlock it. Not so good. Nine.
# 	- 11!
# 	- One, three, five, eight.
# 	- Just a ten.
# 	- Not as good. 11.
# 	- (chuckles) Eight. (groans) Keeping you right in the middle. Make another check.
# 	- Six.
#
#
# ==========================================================================================
#
#
# Cluster 35: 4041 / 258748
# 	- 15 points of damage. (explosion) That one immediately drops what it was eating as the blast slams in
# 	- That's what I'm saying, you're taking half damage from this. You take seven, as opposed to 15.
# 	- 19 points of damage?
# 	- So you take-- that's seven plus 11 points of slashing damage. (whoosh) As it goes to strike a second
# 	- It is necrotic damage, but he has to roll a wisdom saving throw.
# 	- 22 damage? All righty. Got it. Cool, that brings us to-- The general is going to attempt to make a s
# 	- That's not bad. That's eight points of damage and one point of ice damage.
# 	- 23 points of piercing damage and four points of lightning.
# 	- All right. That's (counting) 11 points of damage.
# 	- As a bonus action, I'll smack him again. I will smack him, and then I'll smack him one more time, an
#
#
# ==========================================================================================
#
#
# Cluster 36: 6460 / 258748
# 	- Okay. The somewhat meek female halfling who's now suddenly very reserved, and not as filthy as the h
# 	- Was she not complimenting me?
# 	- Actually she can move ten more feet, so right there.
# 	- Lucien's not going to answer any questions. Molly will answer every question you have later.
# 	- It's what she wants.
# 	- She'll be back.
# 	- For her, yeah, I mean I got to give it to her, yeah.
# 	- The guards already went. Oh, she didn't fire. Sorry, thank you for reminding me about that. The othe
# 	- Did she invite you or all of us?
# 	- Well, she's not currently at her ship. I'm assuming a lot of her valuable information is locked away
#
#
# ==========================================================================================
#
#
# Cluster 37: 2623 / 258748
# 	- Make another perception check.
# 	- You want to make a stealth check one more time? Stealth check first.
# 	- Did you want to land and make an investigation check?
# 	- Make an investigation check. You guys keep just shaking down this poor gnome guy.
# 	- Make an insight check.
# 	- All right. Go ahead and make an investigation check.
# 	- Make an intimidation check.
# 	- Make a strength check. (laughter)
# 	- Roll a stealth check.
# 	- Make a perception check.
#
#
# ==========================================================================================
#
#
# Cluster 38: 6774 / 258748
# 	- That's acrobatics to do that.
# 	- Well, I just don't want anybody to actually stand on a tree for very long.
# 	- This way.
# 	- What's your movement?
# 	- Even then, the ground's going to get--
# 	- I smash (stumbling) mitheens.
# 	- So move over and push into this space--
# 	- Well, that's just pedestrian, really.
# 	- That was the baseline. You run up, it takes all the strength you can feel, you're gonna be sore in t
# 	- Not willy-nilly, not galloping pace.
#
#
# ==========================================================================================
#
#
# Cluster 39: 6240 / 258748
# 	- You know what? It's fine. And I'm going to do the scry.
# 	- Okay. Arbiter Braum.
# 	- I'll go next.
# 	- We're going to stay in order for a second.
# 	- Oh, man. This is going to be fun.
# 	- Oh, let's go! This is on. It's fucking on.
# 	- Come on.
# 	- And yours is up.
# 	- Okay. As you're fussing with this side, that's the end of your turn. All right. Caleb, you're up.
# 	- A round of Trosts for both our tables, please.
#
#
# ==========================================================================================
#
#
# Cluster 40: 5524 / 258748
# 	- Take it away, Mercer.
# 	- Get! You're in the shot, you're in the shot! (laughter)
# 	- Can't say that, ah!
# 	- Ounterloch.
# 	- Boom!
# 	- "Just bring it back-- it's on loan! It's on loan."
# 	- Can I say  Wait!
# 	- That's me!
# 	- No!
# 	- You what?!
#
#
# ==========================================================================================
#
#
# Cluster 41: 3481 / 258748
# 	- 20.
# 	- 24.
# 	- 27.
# 	- 18.
# 	- 14.
# 	- 20.
# 	- 29.
# 	- 20.
# 	- 17.
# 	- 15.
#
#
# ==========================================================================================
#
#
# Cluster 42: 4862 / 258748
# 	- Somebody that was in the castle did this? In my house?
# 	- It's still a mansion. You have an indoor foyer. You can customize any other floor plan you like, and
# 	- And they all look like garbage, so why don't we just start with the garbage downstairs?
# 	- The gate was open, the side gate.
# 	- Is that why it says 'No admittance to the elderly'? You don't want to deal with those riley elderly.
# 	- There is some sort of an enchantment on the door, and the keyhole area itself. You can't ascertain t
# 	- Yep. The false wall in the back.
# 	- Well I could be wrong, but with what I know how to do, I don't think it can do that to this door, fo
# 	- -- a crawlspace through the wall?
# 	- Can I turn, and as I start to close the door behind me, can I look down the hallway and see if anybo
#
#
# ==========================================================================================
#
#
# Cluster 43: 5197 / 258748
# 	- Every time it gets hit, even by spells.
# 	- With that, you aim, take a moment, fire the bullet. You catch it in a way where it doesn't completel
# 	- I pull back from the bite, and I whisper into his ear, I was wondering what was going to break first
# 	- Nice! As you finish spraying it down and all the flesh on the outside of its body is beginning to me
# 	- The shock definitely did a thing?
# 	- Weirdly, the arrow hits and kills Keyleth.
# 	- Okay. As you rush forward, slam once into the back of his shoulder, he kind of falls to one knee aga
# 	- She dodges out of the way, and as you move past, plucks you in the back of the head with a knuckle.
# 	- Okay, you yank it out and there's a streak of blood and you watch as what would be the open axe woun
# 	- The troll spins and goes running with Febron going (screaming) in its grasp, it starts lumbering, le
#
#
# ==========================================================================================
#
#
# Cluster 44: 5693 / 258748
# 	- What are you doing, Vex?
# 	- It's pretty late evening, it's pushing on midnight, yeah.
# 	- Yeah, what do you do, Tary?
# 	- Nott! What do you want to do today?
# 	- Ten minutes.
# 	- I hope so, too. That's all. Have a good night.
# 	- Good night.
# 	- If you feel slightly worse, there's a drink on me.
# 	- Oh good, you're alive!
# 	- Hi, friends. How's it going?
#
#
# ==========================================================================================
#
#
# Cluster 45: 6419 / 258748
# 	- I'm gonna grab Bad News and run up to the crow's nest and see if I can see anything.
# 	- Because I glossed over this last session. Caleb, as you sit there, holding the reins to the horses i
# 	- He pulls out a copper coin that's a little larger than a normal piece of copper and goes, "Just ask
# 	- "Oh well, that's not a worry, I don't think. Simon!" Hits the side of the chair and one of the crown
# 	- "We are the Remnants. Small parts of the whole, given purpose to come together and remake the vessel
# 	- You place your face down into the water, and as opposed to the stone surface you've seen there, it i
# 	- Okay. You Dimension Door into the cyclone. You find yourself on the outside of the wind before it gr
# 	- But you haven't seen any of the guards that were present. All right, cool! While that's happening, y
# 	- You guys climb up the mainmast to the crow's nest, and there you see Avantika with a spyglass, and s
# 	- Grog! The sword pulled you into it! You were dead, your soul was with whatever the fuck is in there
#
#
# ==========================================================================================
#
#
# Cluster 46: 5636 / 258748
# 	- It's like Wisconsin.
# 	- You find all the good stuff.
# 	- What is the geological makeup?
# 	- -- is actually contained beneath the castle.
# 	- Well, you're in the gray. No. Where are you?
# 	- In the water?
# 	- The valley is like a taco shell.
# 	- Do you know of anyone still in the city who would know their way about the sewers?
# 	- Okay, I have a question about this Broad Barn thing. Is Broad Barn the name of an establishment, or
# 	- A lot of people do. This bay, in particular, because this bay is a bastion of trade.
#
#
# ==========================================================================================
#
#
# Cluster 47: 3233 / 258748
# 	- Yeah.
# 	- Yeah.
# 	- Yeah.
# 	- Yeah.
# 	- Yeah!
# 	- Yep.
# 	- Yeah.
# 	- Yeah.
# 	- Yeah.
# 	- Yeah.
#
#
# ==========================================================================================
#
#
# Cluster 48: 1311 / 258748
# 	- You're up after this, Scanlan.
# 	- The sphere dissipates around Scanlan.
# 	- I kick Scanlan a little bit.
# 	- And that's where Scanlan's waiting.
# 	- Scanlan! What are you doing? Cast it!
# 	- It was a very tight roll. It was a DC of 14 in the final roll, and because Scanlan brought out this
# 	- Scanlan?
# 	- Probably not. Not without hitting Scanlan or yourself in the process.
# 	- Scanlan's up?
# 	- Yep. So Scanlan fires the Fireball at Kevdak, it detonates.
#
#
# ==========================================================================================
#
#
# Cluster 49: 2442 / 258748
# 	- Yes, minus five because you're traveling at fast pace.
# 	- Oh, yeah, like what? Ten feet? Yeah?
# 	- Can I get within 60 feet of it?
# 	- Oh you're probably, at this point, about a mile and a half, two miles.
# 	- Am I within 120 feet of the guy that's down?
# 	- Grog, you don't have to worry about it, 'cause you're out of the radius.
# 	- They're below the treeline. Percy, as you get closer you begin to notice that the actual roots of th
# 	- Yeah, going in danger close.
# 	- No, he won't. Even at his full 30-foot movement, he'll be just beyond the 60-foot range.
# 	- 30 feet?!
#
#
# ==========================================================================================
